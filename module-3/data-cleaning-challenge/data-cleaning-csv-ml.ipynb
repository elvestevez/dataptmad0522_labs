# %%
import numpy as np
import pandas as pd
from datetime import date

from sklearn import datasets, ensemble
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.impute import SimpleImputer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_iris = pd.read_csv('iris-data.csv')
df_iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_iris.isnull().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
df_iris.groupby('class').size()
# Out:
# class
# Iris-setosa        49
# Iris-setossa        1
# Iris-versicolor    45
# Iris-virginica     50
# versicolor          5
# dtype: int64

# %%
def rename_class(name):
    new_name = name
    if name == 'Iris-setossa':
        new_name = 'Iris-setosa'
    elif name == 'versicolor':
        new_name = 'Iris-versicolor'
    return new_name

# %%
# correct value of feature class
df_iris['class'] = df_iris.apply(lambda x: rename_class(x['class']), axis=1)
df_iris.groupby('class').size()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# option 1: dropna
print(len(df_iris))
df_iris_new = df_iris.dropna()
print(len(df_iris_new))
df_iris_new.isnull().sum()
# Out:
# 150
# 145
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# class              0
# dtype: int64

# %%
# option 2: assign value mean for same class
print(f"Total mean: {df_iris['petal_width_cm'].mean()}")
print(f"Iris-setosa mean: {df_iris.loc[df_iris['class'] == 'Iris-setosa']['petal_width_cm'].mean()}")
# Out:
# Total mean: 1.2365517241379318
# Iris-setosa mean: 0.25111111111111106

# %%
df_iris.loc[df_iris['class'] == 'Iris-setosa'].sort_values(by=['sepal_length_cm', 
                                                               'sepal_width_cm', 
                                                               'petal_length_cm'])
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 8               4.4             2.9              1.4             NaN
# 38              4.4             3.0              1.3             0.2
# 42              4.4             3.2              1.3             0.2
# 41              4.5             2.3              1.3             0.3
# 3               4.6             3.1              1.5             0.2
# 47              4.6             3.2              1.4             0.2
# 6               4.6             3.4              1.4             0.3
# 22              4.6             3.6              1.0             0.2
# 2               4.7             3.2              1.3             0.2
# 29              4.7             3.2              1.6             0.2
# 12              4.8             3.0              1.4             0.1
# 45              4.8             3.0              1.4             0.3
# 30              4.8             3.1              1.6             0.2
# 11              4.8             3.4              1.6             NaN
# 24              4.8             3.4              1.9             0.2
# 1               4.9             3.0              1.4             0.2
# 9               4.9             3.1              1.5             NaN
# 34              4.9             3.1              1.5             0.1
# 37              4.9             3.1              1.5             0.1
# 25              5.0             3.0              1.6             0.2
# 35              5.0             3.2              1.2             0.2
# 49              5.0             3.3              1.4             0.2
# 7               5.0             3.4              1.5             NaN
# 26              5.0             3.4              1.6             0.4
# 40              5.0             3.5              1.3             0.3
# 43              5.0             3.5              1.6             0.6
# 4               5.0             3.6              1.4             0.2
# 23              5.1             3.3              1.7             0.5
# 39              5.1             3.4              1.5             0.2
# 0               5.1             3.5              1.4             0.2
# 17              5.1             3.5              1.4             0.3
# 21              5.1             3.7              1.5             0.4
# 19              5.1             3.8              1.5             0.3
# 46              5.1             3.8              1.6             0.2
# 44              5.1             3.8              1.9             0.4
# 28              5.2             3.4              1.4             0.2
# 27              5.2             3.5              1.5             0.2
# 32              5.2             4.1              1.5             0.1
# 48              5.3             3.7              1.5             0.2
# 31              5.4             3.4              1.5             0.4
# 20              5.4             3.4              1.7             0.2
# 10              5.4             3.7              1.5             NaN
# 16              5.4             3.9              1.3             0.4
# 5               5.4             3.9              1.7             0.4
# 36              5.5             3.5              1.3             0.2
# 33              5.5             4.2              1.4             0.2
# 13              5.7             3.0              1.1             0.1
# 18              5.7             3.8              1.7             0.3
# 15              5.7             4.4              1.5             0.4
# 14              5.8             4.0              1.2             0.2
#
#           class
# 8   Iris-setosa
# 38  Iris-setosa
# 42  Iris-setosa
# 41  Iris-setosa
# 3   Iris-setosa
# 47  Iris-setosa
# 6   Iris-setosa
# 22  Iris-setosa
# 2   Iris-setosa
# 29  Iris-setosa
# 12  Iris-setosa
# 45  Iris-setosa
# 30  Iris-setosa
# 11  Iris-setosa
# 24  Iris-setosa
# 1   Iris-setosa
# 9   Iris-setosa
# 34  Iris-setosa
# 37  Iris-setosa
# 25  Iris-setosa
# 35  Iris-setosa
# 49  Iris-setosa
# 7   Iris-setosa
# 26  Iris-setosa
# 40  Iris-setosa
# 43  Iris-setosa
# 4   Iris-setosa
# 23  Iris-setosa
# 39  Iris-setosa
# 0   Iris-setosa
# 17  Iris-setosa
# 21  Iris-setosa
# 19  Iris-setosa
# 46  Iris-setosa
# 44  Iris-setosa
# 28  Iris-setosa
# 27  Iris-setosa
# 32  Iris-setosa
# 48  Iris-setosa
# 31  Iris-setosa
# 20  Iris-setosa
# 10  Iris-setosa
# 16  Iris-setosa
# 5   Iris-setosa
# 36  Iris-setosa
# 33  Iris-setosa
# 13  Iris-setosa
# 18  Iris-setosa
# 15  Iris-setosa
# 14  Iris-setosa

# %%
df_iris.iloc[[7, 8, 9, 10, 11]]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
imputer = SimpleImputer(strategy='mean', missing_values=np.nan)
# mean records of Iris-setosa because only there are nulls in this class
imputer = imputer.fit(df_iris.loc[df_iris['class'] == 'Iris-setosa'][['petal_width_cm']])
df_iris['petal_width_cm'] = imputer.transform(df_iris[['petal_width_cm']])

# %%
df_iris.iloc[[7, 8, 9, 10, 11]]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5        0.251111
# 8               4.4             2.9              1.4        0.251111
# 9               4.9             3.1              1.5        0.251111
# 10              5.4             3.7              1.5        0.251111
# 11              4.8             3.4              1.6        0.251111
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
# working with option 2 -> fill null values, no drop

# %%
df_iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.644627        3.054667         3.758667        1.203704
# std           1.312781        0.433123         1.764420        0.763205
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
fig, ax = plt.subplots(figsize=(16,8))

ax = sns.boxplot(data=df_iris[['sepal_length_cm', 
                               'sepal_width_cm', 
                               'petal_length_cm', 
                               'petal_width_cm']])

plt.show()

# %%
fig, axs = plt.subplots(ncols=2,
                        nrows=2,
                        figsize=(16,8))

plt.sca(axs[0,0])
sns.histplot(data=df_iris,
             x='sepal_length_cm')

plt.sca(axs[0,1])
sns.histplot(data=df_iris,
             x='sepal_width_cm')

plt.sca(axs[1,0])
sns.histplot(data=df_iris,
             x='petal_length_cm')

plt.sca(axs[1,1])
sns.histplot(data=df_iris,
             x='petal_width_cm')

plt.show()

# %%
# outliers sepal length
df_iris.loc[(df_iris['sepal_length_cm'] <= (5.1 - 1.5 * (6.4 - 5.1)))]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
# correct the error, multiply by 100 
df_iris.iloc[[77], [0]] = df_iris.iloc[[77], [0]] * 100
df_iris.iloc[[78], [0]] = df_iris.iloc[[78], [0]] * 100
df_iris.iloc[[79], [0]] = df_iris.iloc[[79], [0]] * 100
df_iris.iloc[[80], [0]] = df_iris.iloc[[80], [0]] * 100
df_iris.iloc[[81], [0]] = df_iris.iloc[[81], [0]] * 100

df_iris.iloc[[77, 78, 79, 80, 81]]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77              6.7             3.0              5.0             1.7
# 78              6.0             2.9              4.5             1.5
# 79              5.7             2.6              3.5             1.0
# 80              5.5             2.4              3.8             1.1
# 81              5.5             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
# outliers sepal width
df_iris.loc[(df_iris['sepal_width_cm'] <= (2.8 - 1.5 * (3.3 - 2.8))) |
            (df_iris['sepal_width_cm'] >= (3.3 + 1.5 * (3.3 - 2.8)))]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 15              5.7             4.4              1.5             0.4
# 32              5.2             4.1              1.5             0.1
# 33              5.5             4.2              1.4             0.2
# 60              5.0             2.0              3.5             1.0
#
#               class
# 15      Iris-setosa
# 32      Iris-setosa
# 33      Iris-setosa
# 60  Iris-versicolor

# %%
fig, ax = plt.subplots(figsize=(16,8))

ax = sns.boxplot(data=df_iris[['sepal_length_cm', 
                               'sepal_width_cm', 
                               'petal_length_cm', 
                               'petal_width_cm']])

plt.show()

# %%
fig, axs = plt.subplots(ncols=2,
                        nrows=2,
                        figsize=(16,8))

plt.sca(axs[0,0])
sns.histplot(data=df_iris,
             x='sepal_length_cm')

plt.sca(axs[0,1])
sns.histplot(data=df_iris,
             x='sepal_width_cm')

plt.sca(axs[1,0])
sns.histplot(data=df_iris,
             x='petal_length_cm')

plt.sca(axs[1,1])
sns.histplot(data=df_iris,
             x='petal_width_cm')

plt.show()

# %%
df_iris.corr()
# Out:
#                  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# sepal_length_cm         1.000000       -0.103578         0.850576
# sepal_width_cm         -0.103578        1.000000        -0.419796
# petal_length_cm         0.850576       -0.419796         1.000000
# petal_width_cm          0.805110       -0.359236         0.961173
#
#                  petal_width_cm
# sepal_length_cm        0.805110
# sepal_width_cm        -0.359236
# petal_length_cm        0.961173
# petal_width_cm         1.000000

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax = sns.heatmap(data=df_iris.corr(), 
                 vmin=-1,
                 vmax=1,
                 annot=True)

# %%
# sepal no correlation (you can see outliers before clean)
fig, ax = plt.subplots(figsize=(6,4))
ax = sns.scatterplot(data=df_iris, 
                     x='sepal_length_cm', 
                     y='sepal_width_cm')

# %%
# petal high correlation
fig, ax = plt.subplots(figsize=(6,4))
ax = sns.scatterplot(data=df_iris, 
                     x='petal_length_cm', 
                     y='petal_width_cm')

# %%
# sepal len - petal medium correlation (you can see outliers before clean)
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(12,5))

plt.sca(axs[0])
sns.scatterplot(data=df_iris, 
                x='sepal_length_cm', 
                y='petal_length_cm')

plt.sca(axs[1])
sns.scatterplot(data=df_iris, 
                x='sepal_length_cm', 
                y='petal_width_cm')

plt.show()

# %%
# sepal width - petal no correlation
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(12,5))

plt.sca(axs[0])
sns.scatterplot(data=df_iris, 
                x='sepal_width_cm', 
                y='petal_length_cm')

plt.sca(axs[1])
sns.scatterplot(data=df_iris, 
                x='sepal_width_cm', 
                y='petal_width_cm')

plt.show()

# %%
# correlation with class
fig, axs = plt.subplots(ncols=2,
                        nrows=3,
                        figsize=(12,14))

plt.sca(axs[0,0])
sns.scatterplot(data=df_iris, 
                x='sepal_length_cm', 
                y='sepal_width_cm',
                hue='class')

plt.sca(axs[0,1])
sns.scatterplot(data=df_iris, 
                x='petal_length_cm', 
                y='petal_width_cm',
                hue='class')

plt.sca(axs[1,0])
sns.scatterplot(data=df_iris, 
                x='petal_length_cm', 
                y='sepal_length_cm',
                hue='class')

plt.sca(axs[1,1])
sns.scatterplot(data=df_iris, 
                x='petal_width_cm', 
                y='sepal_length_cm',
                hue='class')

plt.sca(axs[2,0])
sns.scatterplot(data=df_iris, 
                x='petal_length_cm', 
                y='sepal_width_cm',
                hue='class')

plt.sca(axs[2,1])
sns.scatterplot(data=df_iris, 
                x='petal_width_cm', 
                y='sepal_width_cm',
                hue='class')

plt.show()

# %%
# new features size
df_iris_size = df_iris.copy()
df_iris_size['sepal_size'] = df_iris_size.apply(lambda x: x['sepal_length_cm'] * x['sepal_width_cm'], axis=1)
df_iris_size['petal_size'] = df_iris_size.apply(lambda x: x['petal_length_cm'] * x['petal_width_cm'], axis=1)
df_iris_size
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class  sepal_size  petal_size
# 0       Iris-setosa       17.85        0.28
# 1       Iris-setosa       14.70        0.28
# 2       Iris-setosa       15.04        0.26
# 3       Iris-setosa       14.26        0.30
# 4       Iris-setosa       18.00        0.28
# ..              ...         ...         ...
# 145  Iris-virginica       20.10       11.96
# 146  Iris-virginica       15.75       11.50
# 147  Iris-virginica       19.50       10.40
# 148  Iris-virginica       21.08       12.42
# 149  Iris-virginica       17.70        9.18
#
# [150 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax = sns.scatterplot(data=df_iris_size, 
                     x='sepal_size', 
                     y='petal_size',
                     hue='class')

# %%
def set_n_class(name):
    if name == 'Iris-setosa':
        return 1
    elif name == 'Iris-versicolor':
        return 2
    elif name == 'Iris-virginica':
        return 3

# %%
df_iris_size['n_class'] = df_iris_size.apply(lambda x: set_n_class(x['class']), axis=1)

# %%
df_iris_size['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df_iris_size['n_class'].value_counts()
# Out:
# 1    50
# 2    50
# 3    50
# Name: n_class, dtype: int64

# %%
df_iris_size
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class  sepal_size  petal_size  n_class
# 0       Iris-setosa       17.85        0.28        1
# 1       Iris-setosa       14.70        0.28        1
# 2       Iris-setosa       15.04        0.26        1
# 3       Iris-setosa       14.26        0.30        1
# 4       Iris-setosa       18.00        0.28        1
# ..              ...         ...         ...      ...
# 145  Iris-virginica       20.10       11.96        3
# 146  Iris-virginica       15.75       11.50        3
# 147  Iris-virginica       19.50       10.40        3
# 148  Iris-virginica       21.08       12.42        3
# 149  Iris-virginica       17.70        9.18        3
#
# [150 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax = sns.heatmap(data=df_iris_size.corr(), 
                 vmin=-1,
                 vmax=1,
                 annot=True)

# %%
df_iris.to_csv('my-iris-data.csv', index=False)

# %% [markdown]
# ### Notes
# - 150 records.
# - Null values in petal_width_cm (5 rows). Necessary assign value or drop record.
# - Feature class is categorical data. Some errors in values. Necessary assign right value.
# - Data balance (feature class: the same number of records in every class).
# - ¿Scalling? No significantly different.
# - Outliers: big outliers in sepal length and some values in sepal width. ¿Correct/drop? Sepal length could be an error.
# - Mean and median very similar in sepal size (outliers can be affect).
# - Median higher than mean in petal size. More low values.
# - It exists correlation between sepal and petal, width and length:
#     - Sepal width and sepal length, no correlation.
#     - Petal width and petal length, high correlation. Petal width largest, petal length largest too.
#     - Sepal length, medium correlation with petal width and length. Sepal length largest, petal length and width largest too.
# - It exists correlation between size and class. Create new features: size sepal, size petal and n_class:
#     - Petal size small -> setosa.
#     - Petal size medium -> versicolor.
#     - Petal size large -> virginica.
