# %%
import pandas as pd

# %%
list_encoding = ['ascii',
'big5',
'big5hkscs',
'cp037',
'cp273',
'cp424',
'cp437',
'cp500',
'cp720',
'cp737',
'cp775',
'cp850',
'cp852',
'cp855',
'cp856',
'cp857',
'cp858',
'cp860',
'cp861',
'cp862',
'cp863',
'cp864',
'cp865',
'cp866',
'cp869',
'cp874',
'cp875',
'cp932',
'cp949',
'cp950',
'cp1006',
'cp1026',
'cp1125',
'cp1140',
'cp1250',
'cp1251',
'cp1252',
'cp1253',
'cp1254',
'cp1255',
'cp1256',
'cp1257',
'cp1258',
'euc_jp',
'euc_jis_2004',
'euc_jisx0213',
'euc_kr',
'gb2312',
'gbk',
'gb18030',
'hz',
'iso2022_jp',
'iso2022_jp_1',
'iso2022_jp_2',
'iso2022_jp_2004',
'iso2022_jp_3',
'iso2022_jp_ext',
'iso2022_kr',
'latin_1',
'iso8859_2',
'iso8859_3',
'iso8859_4',
'iso8859_5',
'iso8859_6',
'iso8859_7',
'iso8859_8',
'iso8859_9',
'iso8859_10',
'iso8859_11',
'iso8859_13',
'iso8859_14',
'iso8859_15',
'iso8859_16',
'johab',
'koi8_r',
'koi8_t',
'koi8_u',
'kz1048',
'mac_cyrillic',
'mac_greek',
'mac_iceland',
'mac_latin2',
'mac_roman',
'mac_turkish',
'ptcp154',
'shift_jis',
'shift_jis_2004',
'shift_jisx0213',
'utf_32',
'utf_32_be',
'utf_32_le',
'utf_16',
'utf_16_be',
'utf_16_le',
'utf_7',
'utf_8',
'utf_8_sig']
for i in list_encoding:
    try:
        data_shark = pd.read_csv('attacks.csv', encoding=i)
        print(f'{i} encoding ok')
    except:
        pass
# Out:
# cp437 encoding ok
# cp720 encoding ok
# cp737 encoding ok
# cp775 encoding ok
# cp850 encoding ok
# cp852 encoding ok
# cp855 encoding ok
# cp858 encoding ok
# cp860 encoding ok
# cp861 encoding ok
# cp862 encoding ok
# cp863 encoding ok
# cp864 encoding ok
# cp865 encoding ok
# cp866 encoding ok
# cp1006 encoding ok
# cp1125 encoding ok
# cp1250 encoding ok
# cp1251 encoding ok
# cp1252 encoding ok
# cp1254 encoding ok
# cp1256 encoding ok
# latin_1 encoding ok
# iso8859_2 encoding ok
# iso8859_4 encoding ok
# iso8859_5 encoding ok
# iso8859_7 encoding ok
# iso8859_9 encoding ok
# iso8859_10 encoding ok
# iso8859_13 encoding ok
# iso8859_14 encoding ok
# iso8859_15 encoding ok
# iso8859_16 encoding ok
# koi8_r encoding ok
# koi8_u encoding ok
# kz1048 encoding ok
# mac_cyrillic encoding ok
# mac_greek encoding ok
# mac_iceland encoding ok
# mac_latin2 encoding ok
# mac_roman encoding ok
# mac_turkish encoding ok
# ptcp154 encoding ok

# %%
data_shark = pd.read_csv('attacks.csv', encoding='iso8859_15')

# %%
data_shark.info
# Out:
# <bound method DataFrame.info of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...
