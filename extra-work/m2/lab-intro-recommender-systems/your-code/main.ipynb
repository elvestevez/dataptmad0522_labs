# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('../data/customer_product_sales.csv')

# %%
data.head()
# Out:
#    CustomerID FirstName   LastName  SalesID  ProductID           ProductName  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    Quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
# group by customer and product
data_cus_pro = data.groupby(['CustomerID', 'ProductName'])[['Quantity']].sum().reset_index()
data_cus_pro
# Out:
#        CustomerID                    ProductName  Quantity
# 0              33               Apricots - Dried         1
# 1              33              Assorted Desserts         1
# 2              33        Bandage - Flexible Neon         1
# 3              33  Bar Mix - Pina Colada, 355 Ml         1
# 4              33         Beans - Kidney, Canned         1
# ...           ...                            ...       ...
# 63623       98200                   Vol Au Vents        50
# 63624       98200                  Wasabi Powder        25
# 63625       98200       Wine - Fume Blanc Fetzer        25
# 63626       98200  Wine - Hardys Bankside Shiraz        25
# 63627       98200        Yogurt - French Vanilla        25
#
# [63628 rows x 3 columns]

# %%
# check
data.loc[(data['CustomerID'] == 98200) &
         (data['ProductName'] == 'Vol Au Vents')]
# Out:
#       CustomerID FirstName LastName  SalesID  ProductID   ProductName  \
# 4528       98200     Sammy    Rocha  2426936        136  Vol Au Vents
# 4529       98200     Sammy    Rocha  2733410        136  Vol Au Vents
#
#       Quantity
# 4528        25
# 4529        25

# %%
len(data['CustomerID'].unique())
# Out:
# 1000

# %%
len(data['ProductName'].unique())
# Out:
# 452

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
# pivot table for products
data_pivot_pro = pd.pivot_table(data_cus_pro, 
                                values='Quantity', 
                                index=['ProductName'],
                                columns=['CustomerID'], 
                                aggfunc=np.sum, 
                                fill_value=0) # fill_value attribute instead of fillna method
data_pivot_pro
# Out:
# CustomerID                         33     200    264    356    412    464    \
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0      0      0      0
# Apricots - Dried                       1      0      0      0      1      0
# ...                                  ...    ...    ...    ...    ...    ...
# Yeast Dry - Fermipan                   0      0      0      0      0      0
# Yoghurt Tubes                          0      0      0      0      0      0
# Yogurt - Blueberry, 175 Gr             0      1      0      0      0      0
# Yogurt - French Vanilla                1      0      0      1      0      0
# Zucchini - Yellow                      0      0      0      0      0      0
#
# CustomerID                         477    639    649    669    ...  97697  \
# ProductName                                                    ...
# Anchovy Paste - 56 G Tube              0      1      0      0  ...      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0  ...     25
# Appetizer - Mushroom Tart              0      1      0      0  ...     25
# Appetizer - Sausage Rolls              0      0      0      0  ...      0
# Apricots - Dried                       0      0      0      0  ...      0
# ...                                  ...    ...    ...    ...  ...    ...
# Yeast Dry - Fermipan                   0      0      0      0  ...      0
# Yoghurt Tubes                          0      0      2      0  ...      0
# Yogurt - Blueberry, 175 Gr             0      0      0      0  ...     25
# Yogurt - French Vanilla                2      0      0      1  ...      0
# Zucchini - Yellow                      0      0      0      0  ...      0
#
# CustomerID                         97753  97769  97793  97900  97928  98069  \
# ProductName
# Anchovy Paste - 56 G Tube             25      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp     25      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0     25     25     25
# Apricots - Dried                      25      0      0      0      0      0
# ...                                  ...    ...    ...    ...    ...    ...
# Yeast Dry - Fermipan                   0      0     25      0      0      0
# Yoghurt Tubes                          0      0      0      0      0      0
# Yogurt - Blueberry, 175 Gr             0      0     25      0      0      0
# Yogurt - French Vanilla                0     25      0      0      0      0
# Zucchini - Yellow                      0      0      0      0      0      0
#
# CustomerID                         98159  98185  98200
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0
# Appetizer - Mushroom Tart              0     25      0
# Appetizer - Sausage Rolls              0     25      0
# Apricots - Dried                       0      0      0
# ...                                  ...    ...    ...
# Yeast Dry - Fermipan                   0      0      0
# Yoghurt Tubes                         25      0      0
# Yogurt - Blueberry, 175 Gr             0      0      0
# Yogurt - French Vanilla                0      0     25
# Zucchini - Yellow                      0      0      0
#
# [452 rows x 1000 columns]

# %%
# check
data.loc[(data['CustomerID'] == 33) &
         (data['ProductName'] == 'Apricots - Dried')]
# Out:
#        CustomerID FirstName LastName  SalesID  ProductID       ProductName  \
# 45323          33   Lindsay  Santana   172592        324  Apricots - Dried
#
#        Quantity
# 45323         1

# %%
# check
data.loc[(data['CustomerID'] == 33) &
         (data['ProductName'] == 'Yoghurt Tubes')]
# Out:
# Empty DataFrame
# Columns: [CustomerID, FirstName, LastName, SalesID, ProductID, ProductName, Quantity]
# Index: []

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
# pivot table for customers
# traspose previous matrix or pivot_table to original df where columns is ProductName and index is CustomerID
data_pivot_cus = data_pivot_pro.transpose() 
data_pivot_cus
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                                   0                                  0
# 200                                  0                                  0
# 264                                  0                                  0
# 356                                  0                                  0
# 412                                  0                                  0
# ...                                ...                                ...
# 97928                                0                                  0
# 98069                                0                                  0
# 98159                                0                                  0
# 98185                                0                                  0
# 98200                                0                                  0
#
# ProductName  Appetizer - Mushroom Tart  Appetizer - Sausage Rolls  \
# CustomerID
# 33                                   0                          0
# 200                                  0                          0
# 264                                  0                          0
# 356                                  0                          0
# 412                                  0                          0
# ...                                ...                        ...
# 97928                                0                         25
# 98069                                0                         25
# 98159                                0                          0
# 98185                               25                         25
# 98200                                0                          0
#
# ProductName  Apricots - Dried  Apricots - Halves  Apricots Fresh  \
# CustomerID
# 33                          1                  0               0
# 200                         0                  0               0
# 264                         0                  1               1
# 356                         0                  0               0
# 412                         1                  0               0
# ...                       ...                ...             ...
# 97928                       0                 50               0
# 98069                       0                 25               0
# 98159                       0                  0               0
# 98185                       0                 25               0
# 98200                       0                 25              25
#
# ProductName  Arizona - Green Tea  Artichokes - Jerusalem  Assorted Desserts  \
# CustomerID
# 33                             0                       0                  1
# 200                            0                       0                  0
# 264                            0                       0                  0
# 356                            0                       0                  0
# 412                            0                       0                  0
# ...                          ...                     ...                ...
# 97928                         25                       0                  0
# 98069                          0                       0                 25
# 98159                          0                       0                  0
# 98185                          0                       0                  0
# 98200                          0                       0                 25
#
# ProductName  ...  Wine - White, Colubia Cresh  Wine - White, Mosel Gold  \
# CustomerID   ...
# 33           ...                            0                         0
# 200          ...                            1                         0
# 264          ...                            0                         0
# 356          ...                            0                         0
# 412          ...                            0                         1
# ...          ...                          ...                       ...
# 97928        ...                            0                        25
# 98069        ...                            0                         0
# 98159        ...                            0                        50
# 98185        ...                            0                         0
# 98200        ...                            0                         0
#
# ProductName  Wine - White, Schroder And Schyl  Wine - Wyndham Estate Bin 777  \
# CustomerID
# 33                                          0                              0
# 200                                         0                              0
# 264                                         0                              1
# 356                                         0                              0
# 412                                         1                              1
# ...                                       ...                            ...
# 97928                                      25                              0
# 98069                                       0                              0
# 98159                                       0                              0
# 98185                                       0                             25
# 98200                                       0                              0
#
# ProductName  Wonton Wrappers  Yeast Dry - Fermipan  Yoghurt Tubes  \
# CustomerID
# 33                         0                     0              0
# 200                        0                     0              0
# 264                        0                     0              0
# 356                        0                     0              0
# 412                        0                     0              0
# ...                      ...                   ...            ...
# 97928                      0                     0              0
# 98069                      0                     0              0
# 98159                      0                     0             25
# 98185                      0                     0              0
# 98200                      0                     0              0
#
# ProductName  Yogurt - Blueberry, 175 Gr  Yogurt - French Vanilla  \
# CustomerID
# 33                                    0                        1
# 200                                   1                        0
# 264                                   0                        0
# 356                                   0                        1
# 412                                   0                        0
# ...                                 ...                      ...
# 97928                                 0                        0
# 98069                                 0                        0
# 98159                                 0                        0
# 98185                                 0                        0
# 98200                                 0                       25
#
# ProductName  Zucchini - Yellow
# CustomerID
# 33                           0
# 200                          0
# 264                          0
# 356                          0
# 412                          0
# ...                        ...
# 97928                        0
# 98069                        0
# 98159                        0
# 98185                        0
# 98200                        0
#
# [1000 rows x 452 columns]

# %%
# dist
data_dist_cus = pdist(X=data_pivot_cus, metric='euclidean')
data_dist_cus
# Out:
# array([ 11.91637529,  10.48808848,  11.22497216, ..., 304.13812651,
#        305.16389039, 303.10889132])

# %%
# square
data_squa_cus = squareform(data_dist_cus)
data_squa_cus
# Out:
# array([[  0.        ,  11.91637529,  10.48808848, ..., 228.62851966,
#         239.        , 229.77380181],
#        [ 11.91637529,   0.        ,  11.74734012, ..., 228.01096465,
#         239.03765394, 229.70415756],
#        [ 10.48808848,  11.74734012,   0.        , ..., 228.08112592,
#         238.26665734, 229.77380181],
#        ...,
#        [228.62851966, 228.01096465, 228.08112592, ...,   0.        ,
#         304.13812651, 305.16389039],
#        [239.        , 239.03765394, 238.26665734, ..., 304.13812651,
#           0.        , 303.10889132],
#        [229.77380181, 229.70415756, 229.77380181, ..., 305.16389039,
#         303.10889132,   0.        ]])

# %%
# data frame
euclid_dist_cus = pd.DataFrame(data_squa_cus,
                               index=data_pivot_cus.index,
                               columns=data_pivot_cus.index)
print(len(euclid_dist_cus)) # number of rows equals to the different customers
euclid_dist_cus
# Out:
# 1000
# CustomerID       33          200         264         356         412    \
# CustomerID
# 33            0.000000   11.916375   10.488088   11.224972   11.401754
# 200          11.916375    0.000000   11.747340   12.083046   12.569805
# 264          10.488088   11.747340    0.000000   11.489125   11.224972
# 356          11.224972   12.083046   11.489125    0.000000   12.083046
# 412          11.401754   12.569805   11.224972   12.083046    0.000000
# ...                ...         ...         ...         ...         ...
# 97928       220.501701  220.202180  219.136943  219.952268  219.733930
# 98069       217.188858  215.728997  216.612557  217.437347  217.446545
# 98159       228.628520  228.010965  228.081126  228.098663  227.997807
# 98185       239.000000  239.037654  238.266657  238.493186  238.396728
# 98200       229.773802  229.704158  229.773802  229.464594  228.927936
#
# CustomerID       464         477         639         649         669    ...  \
# CustomerID                                                              ...
# 33           11.090537   12.409674   11.045361   11.269428   11.489125  ...
# 200          12.288206   12.165525   12.083046   11.874342   12.000000  ...
# 264          11.445523   12.000000   11.401754   11.180340   11.747340  ...
# 356          11.789826   12.328828   11.135529   11.958261   12.165525  ...
# 412          11.704700   12.328828   11.135529   11.789826   11.747340  ...
# ...                ...         ...         ...         ...         ...  ...
# 97928       219.599636  219.538152  219.924987  219.827205  220.070443  ...
# 98069       217.425849  216.903204  217.294731  217.080630  216.751009  ...
# 98159       228.197283  228.028507  228.181945  227.868383  228.103047  ...
# 98185       239.006276  238.949786  238.468027  238.692271  239.334494  ...
# 98200       229.017467  229.503813  229.656265  229.997826  229.032749  ...
#
# CustomerID       97697       97753       97769       97793       97900  \
# CustomerID
# 33          206.871941  213.180675  225.656819  198.232187  230.913404
# 200         206.310446  212.635839  224.697575  197.139544  230.952376
# 264         206.387984  212.946003  225.435135  197.600607  230.371439
# 356         206.649462  213.082144  225.452878  197.494304  231.038958
# 412         206.900942  211.679002  225.572605  197.630969  230.614397
# ...                ...         ...         ...         ...         ...
# 97928       283.945417  283.945417  302.076149  272.717803  278.388218
# 98069       283.945417  283.945417  295.803989  283.945417  285.043856
# 98159       283.945417  279.508497  300.000000  290.473751  300.000000
# 98185       301.039864  315.238005  306.186218  292.617498  314.245127
# 98200       291.547595  297.909382  294.745653  289.395923  303.108891
#
# CustomerID       97928       98069       98159       98185       98200
# CustomerID
# 33          220.501701  217.188858  228.628520  239.000000  229.773802
# 200         220.202180  215.728997  228.010965  239.037654  229.704158
# 264         219.136943  216.612557  228.081126  238.266657  229.773802
# 356         219.952268  217.437347  228.098663  238.493186  229.464594
# 412         219.733930  217.446545  227.997807  238.396728  228.927936
# ...                ...         ...         ...         ...         ...
# 97928         0.000000  273.861279  291.547595  306.186218  307.205143
# 98069       273.861279    0.000000  287.228132  297.909382  294.745653
# 98159       291.547595  287.228132    0.000000  304.138127  305.163890
# 98185       306.186218  297.909382  304.138127    0.000000  303.108891
# 98200       307.205143  294.745653  305.163890  303.108891    0.000000
#
# [1000 rows x 1000 columns]

# %%
# normalized euclidean custom
def euclid_dist_cus_norm(df_in):
    df_out = pd.DataFrame(1/(1 + squareform(pdist(df_in, 'euclidean'))),
                          index=data_pivot_cus.index,
                          columns=data_pivot_cus.index)
    return df_out


df_euclid_dist_cus = euclid_dist_cus_norm(data_pivot_cus)
df_euclid_dist_cus
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.077421  0.087047  0.081800  0.080634  0.082709
# 200         0.077421  1.000000  0.078448  0.076435  0.073693  0.075255
# 264         0.087047  0.078448  1.000000  0.080070  0.081800  0.080350
# 356         0.081800  0.076435  0.080070  1.000000  0.076435  0.078187
# 412         0.080634  0.073693  0.081800  0.076435  1.000000  0.078711
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.004515  0.004521  0.004543  0.004526  0.004530  0.004533
# 98069       0.004583  0.004614  0.004595  0.004578  0.004578  0.004578
# 98159       0.004355  0.004367  0.004365  0.004365  0.004367  0.004363
# 98185       0.004167  0.004166  0.004179  0.004175  0.004177  0.004167
# 98200       0.004333  0.004335  0.004333  0.004339  0.004349  0.004347
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.074573  0.083020  0.081503  0.080070  ...  0.004811  0.004669
# 200         0.075956  0.076435  0.077674  0.076923  ...  0.004824  0.004681
# 264         0.076923  0.080634  0.082100  0.078448  ...  0.004822  0.004674
# 356         0.075025  0.082403  0.077171  0.075956  ...  0.004816  0.004671
# 412         0.075025  0.082403  0.078187  0.078448  ...  0.004810  0.004702
# ...              ...       ...       ...       ...  ...       ...       ...
# 97928       0.004534  0.004526  0.004528  0.004523  ...  0.003509  0.003509
# 98069       0.004589  0.004581  0.004585  0.004592  ...  0.003509  0.003509
# 98159       0.004366  0.004363  0.004369  0.004365  ...  0.003509  0.003565
# 98185       0.004168  0.004176  0.004172  0.004161  ...  0.003311  0.003162
# 98200       0.004338  0.004335  0.004329  0.004347  ...  0.003418  0.003345
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.004412  0.005019  0.004312  0.004515  0.004583  0.004355
# 200         0.004431  0.005047  0.004311  0.004521  0.004614  0.004367
# 264         0.004416  0.005035  0.004322  0.004543  0.004595  0.004365
# 356         0.004416  0.005038  0.004310  0.004526  0.004578  0.004365
# 412         0.004414  0.005034  0.004318  0.004530  0.004578  0.004367
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.003300  0.003653  0.003579  1.000000  0.003638  0.003418
# 98069       0.003369  0.003509  0.003496  0.003638  1.000000  0.003469
# 98159       0.003322  0.003431  0.003322  0.003418  0.003469  1.000000
# 98185       0.003255  0.003406  0.003172  0.003255  0.003345  0.003277
# 98200       0.003381  0.003444  0.003288  0.003245  0.003381  0.003266
#
# CustomerID     98185     98200
# CustomerID
# 33          0.004167  0.004333
# 200         0.004166  0.004335
# 264         0.004179  0.004333
# 356         0.004175  0.004339
# 412         0.004177  0.004349
# ...              ...       ...
# 97928       0.003255  0.003245
# 98069       0.003345  0.003381
# 98159       0.003277  0.003266
# 98185       1.000000  0.003288
# 98200       0.003288  1.000000
#
# [1000 rows x 1000 columns]

# %%
# normalized cosine custom
def cosine_dist_cus_norm(df_in):
    df_out = pd.DataFrame(1/(1 + squareform(pdist(df_in, 'cosine'))),
                          index=data_pivot_cus.index,
                          columns=data_pivot_cus.index)
    return df_out


df_cosine_dist_cus = cosine_dist_cus_norm(data_pivot_cus)
df_cosine_dist_cus
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.530003  0.563492  0.543546  0.542393  0.541054
# 200         0.530003  1.000000  0.537166  0.535098  0.521226  0.519193
# 264         0.563492  0.537166  1.000000  0.531963  0.550168  0.525368
# 356         0.543546  0.535098  0.531963  1.000000  0.525982  0.523986
# 412         0.542393  0.521226  0.550168  0.525982  1.000000  0.534073
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.513809  0.521925  0.560225  0.530406  0.536686  0.542873
# 98069       0.528795  0.573177  0.548538  0.520138  0.519628  0.520835
# 98159       0.520208  0.537284  0.538340  0.536202  0.538710  0.533856
# 98185       0.529481  0.526167  0.554929  0.544727  0.546943  0.528842
# 98200       0.527142  0.527280  0.527142  0.535974  0.552636  0.552221
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.522016  0.530783  0.533096  0.535293  ...  0.530306  0.517987
# 200         0.556945  0.516729  0.536350  0.541451  ...  0.545224  0.533067
# 264         0.538967  0.514932  0.537046  0.524193  ...  0.546880  0.525550
# 356         0.536792  0.540890  0.516901  0.519482  ...  0.536321  0.520565
# 412         0.542308  0.547743  0.530459  0.543050  ...  0.527903  0.565369
# ...              ...       ...       ...       ...  ...       ...       ...
# 97928       0.540381  0.533190  0.535224  0.526495  ...  0.532674  0.539309
# 98069       0.534221  0.525789  0.531918  0.541402  ...  0.529233  0.535979
# 98159       0.535601  0.535704  0.544926  0.535721  ...  0.542777  0.556893
# 98185       0.527943  0.548943  0.539210  0.518002  ...  0.526429  0.509322
# 98200       0.532238  0.531706  0.519657  0.549685  ...  0.531214  0.526748
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.527662  0.511471  0.534181  0.513809  0.528795  0.520208
# 200         0.555246  0.543554  0.530308  0.521925  0.573177  0.537284
# 264         0.535062  0.531806  0.553085  0.560225  0.548538  0.538340
# 356         0.533119  0.534066  0.528874  0.530406  0.520138  0.536202
# 412         0.528847  0.529278  0.541674  0.536686  0.519628  0.538710
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.522883  0.542570  0.569539  1.000000  0.562050  0.543657
# 98069       0.530224  0.518742  0.554911  0.562050  1.000000  0.548011
# 98159       0.535487  0.521507  0.541404  0.543657  0.548011  1.000000
# 98185       0.537103  0.531411  0.529780  0.531363  0.542143  0.543258
# 98200       0.545760  0.525116  0.537737  0.519127  0.536728  0.531447
#
# CustomerID     98185     98200
# CustomerID
# 33          0.529481  0.527142
# 200         0.526167  0.527280
# 264         0.554929  0.527142
# 356         0.544727  0.535974
# 412         0.546943  0.552636
# ...              ...       ...
# 97928       0.531363  0.519127
# 98069       0.542143  0.536728
# 98159       0.543258  0.531447
# 98185       1.000000  0.546336
# 98200       0.546336  1.000000
#
# [1000 rows x 1000 columns]

# %%
# normalized seuclidean custom
def seuclid_dist_cus_norm(df_in):
    df_out = pd.DataFrame(1/(1 + squareform(pdist(df_in, 'seuclidean'))),
                          index=data_pivot_cus.index,
                          columns=data_pivot_cus.index)
    return df_out


df_seuclid_dist_cus = seuclid_dist_cus_norm(data_pivot_cus)
df_seuclid_dist_cus
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.329359  0.357140  0.343121  0.340994  0.344184
# 200         0.329359  1.000000  0.332622  0.327441  0.318138  0.323041
# 264         0.357140  0.332622  1.000000  0.336855  0.343243  0.336939
# 356         0.343121  0.327441  0.336855  1.000000  0.326678  0.332436
# 412         0.340994  0.318138  0.343243  0.326678  1.000000  0.332313
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.026012  0.026053  0.026172  0.026076  0.026092  0.026114
# 98069       0.026731  0.026913  0.026805  0.026698  0.026699  0.026701
# 98159       0.025289  0.025364  0.025354  0.025365  0.025359  0.025342
# 98185       0.024077  0.024073  0.024162  0.024126  0.024138  0.024083
# 98200       0.024867  0.024868  0.024864  0.024906  0.024954  0.024943
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.319299  0.346258  0.340948  0.333938  ...  0.027534  0.027028
# 200         0.324492  0.328357  0.329472  0.326230  ...  0.027621  0.027098
# 264         0.325941  0.339408  0.342488  0.328753  ...  0.027615  0.027056
# 356         0.319782  0.344991  0.327185  0.321355  ...  0.027573  0.027041
# 412         0.320112  0.345912  0.332289  0.330626  ...  0.027530  0.027215
# ...              ...       ...       ...       ...  ...       ...       ...
# 97928       0.026118  0.026074  0.026095  0.026066  ...  0.020359  0.020360
# 98069       0.026768  0.026723  0.026744  0.026782  ...  0.020438  0.020524
# 98159       0.025357  0.025331  0.025378  0.025351  ...  0.020298  0.020647
# 98185       0.024082  0.024128  0.024110  0.024042  ...  0.019093  0.018386
# 98200       0.024884  0.024877  0.024847  0.024950  ...  0.019703  0.019411
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.025730  0.028987  0.024905  0.026012  0.026731  0.025289
# 200         0.025835  0.029145  0.024898  0.026053  0.026913  0.025364
# 264         0.025748  0.029084  0.024958  0.026172  0.026805  0.025354
# 356         0.025757  0.029094  0.024890  0.026076  0.026698  0.025365
# 412         0.025736  0.029070  0.024929  0.026092  0.026699  0.025359
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.019327  0.021130  0.020566  1.000000  0.021195  0.019802
# 98069       0.019728  0.020497  0.020274  0.021195  1.000000  0.020248
# 98159       0.019418  0.019984  0.019294  0.019802  0.020248  1.000000
# 98185       0.018993  0.019770  0.018364  0.018834  0.019491  0.019030
# 98200       0.019517  0.019881  0.018994  0.018737  0.019565  0.018993
#
# CustomerID     98185     98200
# CustomerID
# 33          0.024077  0.024867
# 200         0.024073  0.024868
# 264         0.024162  0.024864
# 356         0.024126  0.024906
# 412         0.024138  0.024954
# ...              ...       ...
# 97928       0.018834  0.018737
# 98069       0.019491  0.019565
# 98159       0.019030  0.018993
# 98185       1.000000  0.018921
# 98200       0.018921  1.000000
#
# [1000 rows x 1000 columns]

# %%
# normalized correlation custom
def correlation_dist_cus_norm(df_in):
    df_out = pd.DataFrame(1/(1 + squareform(pdist(df_in, 'correlation'))),
                          index=data_pivot_cus.index,
                          columns=data_pivot_cus.index)
    return df_out


df_corr_dist_cus = correlation_dist_cus_norm(data_pivot_cus)
df_corr_dist_cus
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.493776  0.529677  0.510360  0.506951  0.507217
# 200         0.493776  1.000000  0.499733  0.498575  0.482172  0.481921
# 264         0.529677  0.499733  1.000000  0.497579  0.513573  0.490305
# 356         0.510360  0.498575  0.497579  1.000000  0.490143  0.489778
# 412         0.506951  0.482172  0.513573  0.490143  1.000000  0.497577
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.479764  0.484514  0.525278  0.496086  0.500064  0.507963
# 98069       0.493197  0.534491  0.511845  0.484207  0.481259  0.484219
# 98159       0.486457  0.500253  0.503500  0.502204  0.502418  0.499195
# 98185       0.491384  0.484272  0.515736  0.506401  0.505997  0.489667
# 98200       0.492072  0.488735  0.490875  0.500631  0.515015  0.516325
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.487410  0.497932  0.499215  0.502499  ...  0.493385  0.484376
# 200         0.519139  0.480599  0.499131  0.505459  ...  0.504719  0.496170
# 264         0.503243  0.480936  0.502028  0.490242  ...  0.508803  0.490805
# 356         0.501933  0.507803  0.482686  0.486354  ...  0.499105  0.486660
# 412         0.505111  0.512470  0.493947  0.507777  ...  0.488109  0.529502
# ...              ...       ...       ...       ...  ...       ...       ...
# 97928       0.504739  0.499300  0.500268  0.492619  ...  0.494577  0.504692
# 98069       0.496892  0.490306  0.495330  0.506038  ...  0.489353  0.499742
# 98159       0.500240  0.502118  0.510333  0.502173  ...  0.505074  0.522726
# 98185       0.487961  0.511136  0.500094  0.480046  ...  0.483728  0.470481
# 98200       0.495461  0.496775  0.483588  0.514917  ...  0.491940  0.491017
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.493486  0.479867  0.499870  0.479764  0.493197  0.486457
# 200         0.517884  0.508954  0.492581  0.484514  0.534491  0.500253
# 264         0.499750  0.499162  0.517743  0.525278  0.511845  0.503500
# 356         0.498662  0.502228  0.494239  0.496086  0.484207  0.502204
# 412         0.492033  0.495264  0.504752  0.500064  0.481259  0.502418
# ...              ...       ...       ...       ...       ...       ...
# 97928       0.487604  0.510055  0.534474  1.000000  0.525583  0.508923
# 98069       0.493332  0.484621  0.518025  0.525583  1.000000  0.511707
# 98159       0.500553  0.489177  0.506341  0.508923  0.511707  1.000000
# 98185       0.497652  0.494943  0.490103  0.492050  0.501063  0.504367
# 98200       0.509511  0.491520  0.501261  0.482921  0.498897  0.495580
#
# CustomerID     98185     98200
# CustomerID
# 33          0.491384  0.492072
# 200         0.484272  0.488735
# 264         0.515736  0.490875
# 356         0.506401  0.500631
# 412         0.505997  0.515015
# ...              ...       ...
# 97928       0.492050  0.482921
# 98069       0.501063  0.498897
# 98159       0.504367  0.495580
# 98185       1.000000  0.505914
# 98200       0.505914  1.000000
#
# [1000 rows x 1000 columns]

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
# top 5 most similar customers for id 33 for example
idcustomer = 33
similar_cus = pd.DataFrame(df_euclid_dist_cus.loc[idcustomer].sort_values(ascending=False))[1:6]
similar_cus
# Out:
#                   33
# CustomerID
# 3317        0.087047
# 3535        0.087047
# 264         0.087047
# 2503        0.085983
# 3305        0.085638

# %%
# top 5 most similar customers for id 264 for example (33 is most similar customer from 264 and reverse)
idcustomer = 264
similar_cus = pd.DataFrame(df_euclid_dist_cus.loc[idcustomer].sort_values(ascending=False))[1:6]
similar_cus
# Out:
#                  264
# CustomerID
# 1008        0.088152
# 2617        0.088152
# 1072        0.087410
# 33          0.087047
# 3535        0.086333

# %%
# top 5 most similar customers for id 3305 for example (in this case 33 is not most similar, but yes in other way)
idcustomer = 3305
similar_cus = pd.DataFrame(df_euclid_dist_cus.loc[idcustomer].sort_values(ascending=False))[1:6]
similar_cus
# Out:
#                 3305
# CustomerID
# 1072        0.088913
# 3317        0.088530
# 883         0.088530
# 3535        0.088530
# 3074        0.087779

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
# similar customers for id 97928 for example
idcustomer = 97928
similar_cus = pd.DataFrame(df_euclid_dist_cus.loc[idcustomer].sort_values(ascending=False))[1:6]
customers = similar_cus.reset_index()[['CustomerID']]
customers
# Out:
#    CustomerID
# 0       42087
# 1       18622
# 2       14012
# 3       18796
# 4       13062

# %%
data_cus_pro.head()
# Out:
#    CustomerID                    ProductName  Quantity
# 0          33               Apricots - Dried         1
# 1          33              Assorted Desserts         1
# 2          33        Bandage - Flexible Neon         1
# 3          33  Bar Mix - Pina Colada, 355 Ml         1
# 4          33         Beans - Kidney, Canned         1

# %%
# join df similar customers and data customers and products
records_cus_pro = data_cus_pro.merge(customers)
records_cus_pro
# Out:
#      CustomerID                        ProductName  Quantity
# 0         13062  Appetizer - Mini Egg Roll, Shrimp         4
# 1         13062          Appetizer - Mushroom Tart         4
# 2         13062                  Assorted Desserts         4
# 3         13062         Bacardi Breezer - Tropical         4
# 4         13062                      Baking Powder         4
# ..          ...                                ...       ...
# 359       42087         Wine - Two Oceans Cabernet        11
# 360       42087  Wine - Vineland Estate Semi - Dry        11
# 361       42087               Yeast Dry - Fermipan        11
# 362       42087         Yogurt - Blueberry, 175 Gr        11
# 363       42087            Yogurt - French Vanilla        11
#
# [364 rows x 3 columns]

# %%
# check number of rows
data_cus_pro.loc[(data_cus_pro['CustomerID'] == 264) |
                 (data_cus_pro['CustomerID'] == 2503) |
                 (data_cus_pro['CustomerID'] == 3305) |
                 (data_cus_pro['CustomerID'] == 3317) |
                 (data_cus_pro['CustomerID'] == 3535)].groupby('CustomerID')[['ProductName']].count()
# Out:
#             ProductName
# CustomerID
# 264                  62
# 2503                 47
# 3305                 54
# 3317                 52
# 3535                 55

# %%
# check number of rows 
records_cus_pro.groupby('CustomerID')[['ProductName']].count()
# Out:
#             ProductName
# CustomerID
# 13062                67
# 14012                80
# 18622                70
# 18796                77
# 42087                70

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
# top products 5 similar customers (for specific id customer)
top_products = records_cus_pro.groupby(['ProductName'])[['Quantity']].sum().sort_values(by='Quantity', 
                                                                                        ascending=False).reset_index()
top_products
# Out:
#                        ProductName  Quantity
# 0      Bouq All Italian - Primerba        35
# 1               Tea - Jasmin Green        32
# 2         Soup - Campbells, Lentil        27
# 3              Arizona - Green Tea        26
# 4             Cheese - Brie,danish        25
# ..                             ...       ...
# 251            Cheese Cloth No 100         4
# 252                Grouper - Fresh         4
# 253  Bread Crumbs - Japanese Style         4
# 254                Skirt - 29 Foot         4
# 255                    Guinea Fowl         4
#
# [256 rows x 2 columns]

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
# idcustomer selected previous step
customer = data_cus_pro[(data_cus_pro['CustomerID'] == idcustomer)]
# join products and data customers and products
records_top_pro = customer.merge(top_products, how='right', left_on='ProductName', right_on='ProductName')
# select products not purchased
list_products = list(records_top_pro[records_top_pro['CustomerID'].isnull()][:5]['ProductName'])
list_products
# Out:
# ['Soup - Campbells, Lentil',
#  'Cheese - Brie,danish',
#  'Wiberg Super Cure',
#  'Pants Custom Dry Clean',
#  'Shrimp - 31/40']

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
# top 5 customer distance euclide

list_customers = []
# go every customer
### to test a few customers -> for idcustom in data_cus_pro['CustomerID'].unique()[:3]:
for idcustom in data_cus_pro['CustomerID'].unique():
    # choose similar customers
    similar_cus = pd.DataFrame(df_euclid_dist_cus.loc[idcustom].sort_values(ascending=False))[1:6]
    similar_customers = similar_cus.reset_index()[['CustomerID']]
    # join similar customers and data customers and products
    records_cus_pro = data_cus_pro.merge(similar_customers)
    # choose top products
    top_products = records_cus_pro.groupby(['ProductName'])[['Quantity']].sum().sort_values(by='Quantity', ascending=False)
    # products not purchased
    customer = data_cus_pro[(data_cus_pro['CustomerID'] == idcustom)]
    # join products and data customers and products
    records_top_pro = customer.merge(top_products, how='right', left_on='ProductName', right_on='ProductName')
    # select products not purchased
    list_products = list(records_top_pro[records_top_pro['CustomerID'].isnull()][:5]['ProductName'])
    # dictionary
    dict_customers = {}
    dict_customers['CustomerID'] = idcustom
    dict_customers['Products'] = list_products
    # add customer
    list_customers.append(dict_customers)
print(len(list_customers)) # 1000 should be total of customers
list_customers
# Out:
# 1000
# [{'CustomerID': 33,
#   'Products': ['Butter - Unsalted',
#    'Wine - Ej Gallo Sierra Valley',
#    'Soup - Campbells Bean Medley',
#    'Wine - Blue Nun Qualitatswein',
#    'Chicken - Soup Base']},
#  {'CustomerID': 200,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Muffin - Carrot Individual Wrap',
#    'Bay Leaf',
#    'Pork - Kidney',
#    'Wanton Wrap']},
#  {'CustomerID': 264,
#   'Products': ['Soupfoamcont12oz 112con',
#    'Wine - Two Oceans Cabernet',
#    'Bread - Italian Roll With Herbs',
#    'Veal - Inside, Choice',
#    'Fish - Scallops, Cold Smoked']},
#  {'CustomerID': 356,
#   'Products': ['Butter - Unsalted',
#    'Veal - Inside, Choice',
#    'Beets - Candy Cane, Organic',
#    'Nut - Chestnuts, Whole',
#    'Lamb - Ground']},
#  {'CustomerID': 412,
#   'Products': ['Olive - Spread Tapenade',
#    'Sprouts - Baby Pea Tendrils',
#    'Wine - Blue Nun Qualitatswein',
#    'Pepper - Black, Whole',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 464,
#   'Products': ['Butter - Unsalted',
#    'Sauce - Gravy, Au Jus, Mix',
#    'Pepper - Black, Whole',
#    'Peas - Pigeon, Dry',
#    'Bar - Granola Trail Mix Fruit Nut']},
#  {'CustomerID': 477,
#   'Products': ['Olive - Spread Tapenade',
#    'Sprouts - Baby Pea Tendrils',
#    'Wine - Blue Nun Qualitatswein',
#    'Veal - Inside, Choice',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 639,
#   'Products': ['Cod - Black Whole Fillet',
#    'Wine - Ej Gallo Sierra Valley',
#    'Yoghurt Tubes',
#    'Pepper - Black, Whole',
#    'Soupfoamcont12oz 112con']},
#  {'CustomerID': 649,
#   'Products': ['Bar - Granola Trail Mix Fruit Nut',
#    'Wine - Magnotta - Belpaese',
#    'Appetizer - Mushroom Tart',
#    'Peas - Pigeon, Dry',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 669,
#   'Products': ['Veal - Inside, Choice',
#    'Sardines',
#    'Wine - Ej Gallo Sierra Valley',
#    'Pepper - Black, Whole',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 694,
#   'Products': ['Bar - Granola Trail Mix Fruit Nut',
#    'Potatoes - Idaho 100 Count',
#    'Beets - Candy Cane, Organic',
#    'Knife Plastic - White',
#    'Sardines']},
#  {'CustomerID': 756,
#   'Products': ['Veal - Inside, Choice',
#    'Grouper - Fresh',
#    'Salsify, Organic',
#    'Butter - Unsalted',
#    'Peas - Pigeon, Dry']},
#  {'CustomerID': 883,
#   'Products': ['Knife Plastic - White',
#    'Sardines',
#    'Soup Campbells - Italian Wedding',
#    'Beef Wellington',
#    'Salsify, Organic']},
#  {'CustomerID': 891,
#   'Products': ['Cod - Black Whole Fillet',
#    'Soup - Campbells Bean Medley',
#    'Sherry - Dry',
#    'Pepper - Black, Whole',
#    'Sprouts - Baby Pea Tendrils']},
#  {'CustomerID': 1008,
#   'Products': ['Mushrooms - Black, Dried',
#    'Lamb - Ground',
#    'Soupfoamcont12oz 112con',
#    'Pepper - Black, Whole',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 1034,
#   'Products': ['Beef - Top Sirloin - Aaa',
#    'Wine - Chardonnay South',
#    'Eggplant - Asian',
#    'Sole - Dover, Whole, Fresh',
#    'Veal - Sweetbread']},
#  {'CustomerID': 1066,
#   'Products': ['Butter - Unsalted',
#    'Wine - Blue Nun Qualitatswein',
#    'Yoghurt Tubes',
#    'Knife Plastic - White',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 1072,
#   'Products': ['Nut - Chestnuts, Whole',
#    'Skirt - 29 Foot',
#    'Pork - Bacon, Double Smoked',
#    'Butter - Unsalted',
#    'Bar - Granola Trail Mix Fruit Nut']},
#  {'CustomerID': 1336,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Butter - Unsalted',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Pepper - Black, Whole',
#    'Wine - Crozes Hermitage E.']},
#  {'CustomerID': 1428,
#   'Products': ['Ketchup - Tomato',
#    'Cake - Cake Sheet Macaroon',
#    'Cheese - Cambozola',
#    'Anchovy Paste - 56 G Tube',
#    'Peas - Pigeon, Dry']},
#  {'CustomerID': 1435,
#   'Products': ['Sherry - Dry',
#    'Bandage - Fexible 1x3',
#    'Extract - Lemon',
#    'Fish - Scallops, Cold Smoked',
#    'Knife Plastic - White']},
#  {'CustomerID': 1534,
#   'Products': ['Pepper - Black, Whole',
#    'Wine - Blue Nun Qualitatswein',
#    'Soup - Campbells Bean Medley',
#    'Knife Plastic - White',
#    'Muffin Batt - Blueberry Passion']},
#  {'CustomerID': 1577,
#   'Products': ['Soupfoamcont12oz 112con',
#    'Veal - Inside, Choice',
#    'Knife Plastic - White',
#    'Butter - Unsalted',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 1594,
#   'Products': ['Tart Shells - Sweet, 4',
#    'Muffin - Carrot Individual Wrap',
#    'Soup - Campbells Bean Medley',
#    'Cheese - Brie, Triple Creme',
#    'Lamb - Ground']},
#  {'CustomerID': 1754,
#   'Products': ['Bandage - Fexible 1x3',
#    'Yoghurt Tubes',
#    'Wine - Chardonnay South',
#    'Knife Plastic - White',
#    'Sprouts - Baby Pea Tendrils']},
#  {'CustomerID': 1839,
#   'Products': ['Bar - Granola Trail Mix Fruit Nut',
#    'Ketchup - Tomato',
#    'Fenngreek Seed',
#    'Wine - Magnotta - Belpaese',
#    'Appetizer - Mushroom Tart']},
#  {'CustomerID': 1920,
#   'Products': ['Wine - Blue Nun Qualitatswein',
#    'Beef Wellington',
#    'Sardines',
#    'Knife Plastic - White',
#    'Ketchup - Tomato']},
#  {'CustomerID': 2187,
#   'Products': ['Sausage - Breakfast',
#    'Bandage - Fexible 1x3',
#    'Beef - Texas Style Burger',
#    'Butter - Unsalted',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 2329,
#   'Products': ['Knife Plastic - White',
#    'Butter - Unsalted',
#    'Beets - Candy Cane, Organic',
#    'Whmis - Spray Bottle Trigger',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 2503,
#   'Products': ['Sole - Dover, Whole, Fresh',
#    'Whmis - Spray Bottle Trigger',
#    'Foam Dinner Plate',
#    'Table Cloth 54x72 White',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 2556,
#   'Products': ['Lamb - Ground',
#    'Butter - Unsalted',
#    'Juice - Orange',
#    'Soupfoamcont12oz 112con',
#    'Muffin - Carrot Individual Wrap']},
#  {'CustomerID': 2566,
#   'Products': ['Wine - Ej Gallo Sierra Valley',
#    'Wine - Blue Nun Qualitatswein',
#    'Wine - Chardonnay South',
#    'Water, Tap',
#    'Beef Wellington']},
#  {'CustomerID': 2582,
#   'Products': ['Butter - Unsalted',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Beef - Montreal Smoked Brisket',
#    'Knife Plastic - White',
#    'Tia Maria']},
#  {'CustomerID': 2617,
#   'Products': ['Yoghurt Tubes',
#    'Soup - Campbells Bean Medley',
#    'Wine - Blue Nun Qualitatswein',
#    'Pepper - Black, Whole',
#    'Chocolate - Dark']},
#  {'CustomerID': 2686,
#   'Products': ['Butter - Unsalted',
#    'Pepper - Black, Whole',
#    'Soup - Campbells Bean Medley',
#    'Cod - Black Whole Fillet',
#    'Bandage - Fexible 1x3']},
#  {'CustomerID': 2754,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Pepper - Black, Whole',
#    'Knife Plastic - White',
#    'Foam Dinner Plate',
#    'Butter - Unsalted']},
#  {'CustomerID': 2776,
#   'Products': ['Nut - Chestnuts, Whole',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Soup - Campbells Bean Medley',
#    'Wine - Blue Nun Qualitatswein',
#    'Knife Plastic - White']},
#  {'CustomerID': 2902,
#   'Products': ['Yoghurt Tubes',
#    'Butter - Unsalted',
#    'Fish - Scallops, Cold Smoked',
#    'Knife Plastic - White',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 2915,
#   'Products': ['Butter - Unsalted',
#    'Beef - Montreal Smoked Brisket',
#    'Pepper - Black, Whole',
#    'Wine - Blue Nun Qualitatswein',
#    'Knife Plastic - White']},
#  {'CustomerID': 2939,
#   'Products': ['Butter - Unsalted',
#    'Yoghurt Tubes',
#    'Knife Plastic - White',
#    'Pepper - Black, Whole',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 3074,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Beef Wellington',
#    'Bay Leaf',
#    'Wine - Blue Nun Qualitatswein',
#    'Oranges - Navel, 72']},
#  {'CustomerID': 3253,
#   'Products': ['Bar - Granola Trail Mix Fruit Nut',
#    'Yoghurt Tubes',
#    'Nut - Chestnuts, Whole',
#    'Sausage - Breakfast',
#    'Bandage - Fexible 1x3']},
#  {'CustomerID': 3267,
#   'Products': ['Sole - Dover, Whole, Fresh',
#    'Whmis - Spray Bottle Trigger',
#    'Foam Dinner Plate',
#    'Table Cloth 54x72 White',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 3305,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Sherry - Dry',
#    'Pepper - Black, Whole',
#    'Sprouts - Baby Pea Tendrils',
#    'Wine - Chardonnay South']},
#  {'CustomerID': 3317,
#   'Products': ['Bar - Granola Trail Mix Fruit Nut',
#    'Sausage - Breakfast',
#    'Yoghurt Tubes',
#    'Fish - Scallops, Cold Smoked',
#    'Knife Plastic - White']},
#  {'CustomerID': 3472,
#   'Products': ['Pepper - Black, Whole',
#    'Knife Plastic - White',
#    'Butter - Unsalted',
#    'Wine - Ej Gallo Sierra Valley',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 3531,
#   'Products': ['Lamb - Pieces, Diced',
#    'Veal - Sweetbread',
#    'Butter - Unsalted',
#    'Wine - Gato Negro Cabernet',
#    'Knife Plastic - White']},
#  {'CustomerID': 3535,
#   'Products': ['Butter - Unsalted',
#    'Muffin - Carrot Individual Wrap',
#    'Otomegusa Dashi Konbu',
#    'Knife Plastic - White',
#    'Lemonade - Natural, 591 Ml']},
#  {'CustomerID': 3544,
#   'Products': ['Mushrooms - Black, Dried',
#    'Beef - Top Sirloin',
#    'Wine - Chablis 2003 Champs',
#    'Chocolate - Dark',
#    'Tart Shells - Sweet, 4']},
#  {'CustomerID': 3885,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Sherry - Dry',
#    'Butter - Unsalted',
#    'Doilies - 5, Paper',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 3903,
#   'Products': ['Pepper - Black, Whole',
#    'Knife Plastic - White',
#    'Butter - Unsalted',
#    'Wine - Ej Gallo Sierra Valley',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 3909,
#   'Products': ['Pepper - Black, Whole',
#    'Soupfoamcont12oz 112con',
#    'Fondant - Icing',
#    'Cod - Black Whole Fillet',
#    'Veal - Inside, Choice']},
#  {'CustomerID': 4261,
#   'Products': ['Sobe - Tropical Energy',
#    'Sherry - Dry',
#    'Soup - Campbells Bean Medley',
#    'Grouper - Fresh',
#    'Mayonnaise - Individual Pkg']},
#  {'CustomerID': 4479,
#   'Products': ['Turkey - Oven Roast Breast',
#    'Tia Maria',
#    'Wine - Gato Negro Cabernet',
#    'Loquat',
#    'Veal - Brisket, Provimi,bnls']},
#  {'CustomerID': 4595,
#   'Products': ['Wine - Magnotta, Merlot Sr Vqa',
#    'Cod - Black Whole Fillet',
#    'Scallops - 10/20',
#    'Halibut - Steaks',
#    'Bread - Rye']},
#  {'CustomerID': 4644,
#   'Products': ['Salsify, Organic',
#    'Pork - Bacon, Double Smoked',
#    'Lamb - Pieces, Diced',
#    'Tofu - Firm',
#    'Lettuce - Spring Mix']},
#  {'CustomerID': 4723,
#   'Products': ['Sole - Dover, Whole, Fresh',
#    'Oregano - Dry, Rubbed',
#    'Foam Dinner Plate',
#    'Wine - Blue Nun Qualitatswein',
#    'Water, Tap']},
#  {'CustomerID': 5104,
#   'Products': ['Bread - Rye',
#    'Mayonnaise - Individual Pkg',
#    'Cheese Cloth No 100',
#    'Rambutan',
#    'Rabbit - Whole']},
#  {'CustomerID': 5177,
#   'Products': ['Cocktail Napkin Blue',
#    'Soupfoamcont12oz 112con',
#    'Sea Bass - Whole',
#    'Pork - Loin, Center Cut',
#    'Sole - Dover, Whole, Fresh']},
#  {'CustomerID': 5183,
#   'Products': ['Table Cloth 54x72 White',
#    'Cheese Cloth No 100',
#    'Olive - Spread Tapenade',
#    'Pail For Lid 1537',
#    'Phyllo Dough']},
#  {'CustomerID': 5224,
#   'Products': ['Salsify, Organic',
#    'Knife Plastic - White',
#    'Soupfoamcont12oz 112con',
#    'Bar Mix - Pina Colada, 355 Ml',
#    'Bar - Granola Trail Mix Fruit Nut']},
#  {'CustomerID': 5230,
#   'Products': ['Tart Shells - Sweet, 4',
#    'Black Currants',
#    'Squid U5 - Thailand',
#    'Muffin - Carrot Individual Wrap',
#    'Pork - Kidney']},
#  {'CustomerID': 5434,
#   'Products': ['Sherry - Dry',
#    'Pasta - Penne, Rigate, Dry',
#    'Soup - Campbells Bean Medley',
#    'Smirnoff Green Apple Twist',
#    'Berry Brulee']},
#  {'CustomerID': 5678,
#   'Products': ['Veal - Sweetbread',
#    'Mayonnaise - Individual Pkg',
#    'Tia Maria',
#    'Juice - Cranberry, 341 Ml',
#    'Cinnamon Buns Sticky']},
#  {'CustomerID': 5739,
#   'Products': ['Soupfoamcont12oz 112con',
#    'Lamb - Pieces, Diced',
#    'Soup - Campbells Bean Medley',
#    'Otomegusa Dashi Konbu',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 5832,
#   'Products': ['Pepper - White, Ground',
#    'Veal - Inside, Choice',
#    'Veal - Sweetbread',
#    'Beef - Top Sirloin',
#    'Tia Maria']},
#  {'CustomerID': 5921,
#   'Products': ['Ketchup - Tomato',
#    'Pepper - Black, Whole',
#    'Squid - Tubes / Tenticles 10/20',
#    'Soup - Campbells Bean Medley',
#    'Wine - Toasted Head']},
#  {'CustomerID': 5968,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Pork - Kidney',
#    'Durian Fruit',
#    'Cheese - Cheddarsliced',
#    'Bar - Granola Trail Mix Fruit Nut']},
#  {'CustomerID': 5986,
#   'Products': ['Wine - Chardonnay South',
#    'Wine - Gato Negro Cabernet',
#    'Muffin - Carrot Individual Wrap',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Wine - White, Colubia Cresh']},
#  {'CustomerID': 5997,
#   'Products': ['Bacardi Breezer - Tropical',
#    'Chicken - Leg, Boneless',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Mussels - Frozen',
#    'Tahini Paste']},
#  {'CustomerID': 6001,
#   'Products': ['Veal - Inside, Choice',
#    'Wine - Toasted Head',
#    'Black Currants',
#    'Oranges - Navel, 72',
#    'Pork - Kidney']},
#  {'CustomerID': 6185,
#   'Products': ['Beef - Texas Style Burger',
#    'Mushrooms - Black, Dried',
#    'Muffin - Carrot Individual Wrap',
#    'Lettuce - Spring Mix',
#    'Hersey Shakes']},
#  {'CustomerID': 6317,
#   'Products': ['Pasta - Penne, Rigate, Dry',
#    'Soup - Campbells, Lentil',
#    'Wine - Blue Nun Qualitatswein',
#    'Sardines',
#    'Sprouts - Baby Pea Tendrils']},
#  {'CustomerID': 6352,
#   'Products': ['Pasta - Cheese / Spinach Bauletti',
#    'Vinegar - Tarragon',
#    'Lamb - Ground',
#    'Soupfoamcont12oz 112con',
#    'Beef - Top Sirloin']},
#  {'CustomerID': 6367,
#   'Products': ['Scampi Tail',
#    'Wine - Crozes Hermitage E.',
#    'Water, Tap',
#    'Beef - Texas Style Burger',
#    'Bar - Granola Trail Mix Fruit Nut']},
#  {'CustomerID': 6447,
#   'Products': ['Rice - Long Grain',
#    'Turkey - Oven Roast Breast',
#    'Sprouts - Baby Pea Tendrils',
#    'Sea Bass - Whole',
#    'Crab - Imitation Flakes']},
#  {'CustomerID': 6543,
#   'Products': ['Pork - Kidney',
#    'Bread - Italian Corn Meal Poly',
#    'Kellogs Special K Cereal',
#    'Lettuce - Spring Mix',
#    'Scallop - St. Jaques']},
#  {'CustomerID': 6734,
#   'Products': ['Ezy Change Mophandle',
#    'Ice Cream Bar - Hageen Daz To',
#    'Wine - White, Colubia Cresh',
#    'Wine - Magnotta - Belpaese',
#    'Wine - Ej Gallo Sierra Valley']},
#  {'CustomerID': 6817,
#   'Products': ['Pasta - Cheese / Spinach Bauletti',
#    'Sherry - Dry',
#    'Vinegar - Tarragon',
#    'Cocktail Napkin Blue',
#    'Lamb - Ground']},
#  {'CustomerID': 6851,
#   'Products': ['Soupfoamcont12oz 112con',
#    'Cheese - Wine',
#    'Cheese Cloth No 100',
#    'Lamb - Ground',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 7021,
#   'Products': ['Yoghurt Tubes',
#    'Pork - Kidney',
#    'Ice Cream Bar - Hageen Daz To',
#    'Chinese Foods - Chicken',
#    'Potatoes - Idaho 100 Count']},
#  {'CustomerID': 7134,
#   'Products': ['Cheese Cloth No 100',
#    'Wine - Charddonnay Errazuriz',
#    'Tea - Jasmin Green',
#    'Lamb - Pieces, Diced',
#    'Lamb - Ground']},
#  {'CustomerID': 7223,
#   'Products': ['Curry Paste - Madras',
#    'Beef - Texas Style Burger',
#    'Pepper - Black, Whole',
#    'Cod - Black Whole Fillet',
#    'Soupfoamcont12oz 112con']},
#  {'CustomerID': 7543,
#   'Products': ['Durian Fruit',
#    'Zucchini - Yellow',
#    'Eggplant - Asian',
#    'Flavouring - Orange',
#    'Pecan Raisin - Tarts']},
#  {'CustomerID': 7606,
#   'Products': ['Pomello',
#    'Wine - Toasted Head',
#    'Pork - Loin, Center Cut',
#    'Wine - Chardonnay South',
#    'Flavouring - Orange']},
#  {'CustomerID': 7623,
#   'Products': ['Sausage - Breakfast',
#    'Pepper - Paprika, Hungarian',
#    'Wine - Magnotta - Belpaese',
#    'Ezy Change Mophandle',
#    'Foam Dinner Plate']},
#  {'CustomerID': 7772,
#   'Products': ['Juice - Apple Cider',
#    'Lime Cordial - Roses',
#    'Pork - Hock And Feet Attached',
#    'Ice Cream Bar - Hageen Daz To',
#    'Beef - Texas Style Burger']},
#  {'CustomerID': 7827,
#   'Products': ['Cod - Black Whole Fillet',
#    'Ice Cream Bar - Oreo Cone',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Cumin - Whole',
#    'Extract - Lemon']},
#  {'CustomerID': 7987,
#   'Products': ['Cheese - Taleggio D.o.p.',
#    'Ice Cream Bar - Hageen Daz To',
#    'Bread - Italian Roll With Herbs',
#    'Rabbit - Whole',
#    'Knife Plastic - White']},
#  {'CustomerID': 7999,
#   'Products': ['Otomegusa Dashi Konbu',
#    'Thyme - Lemon, Fresh',
#    'Wine - Magnotta - Belpaese',
#    'Mayonnaise - Individual Pkg',
#    'Sobe - Tropical Energy']},
#  {'CustomerID': 8316,
#   'Products': ['Beef - Texas Style Burger',
#    'Yoghurt Tubes',
#    'Scampi Tail',
#    'Cocktail Napkin Blue',
#    'Turkey - Oven Roast Breast']},
#  {'CustomerID': 8367,
#   'Products': ['Chicken - Leg, Boneless',
#    'Potatoes - Idaho 100 Count',
#    'Sauerkraut',
#    'Crackers - Trio',
#    'Wine - Crozes Hermitage E.']},
#  {'CustomerID': 8372,
#   'Products': ['Pie Filling - Cherry',
#    'Soupfoamcont12oz 112con',
#    'Ecolab - Lime - A - Way 4/4 L',
#    'Wanton Wrap',
#    'Beans - Wax']},
#  {'CustomerID': 8539,
#   'Products': ['Bread - Calabrese Baguette',
#    'Wine - Pinot Noir Latour',
#    'Wine - Crozes Hermitage E.',
#    'Crab - Imitation Flakes',
#    'Sunflower Seed Raw']},
#  {'CustomerID': 8711,
#   'Products': ['Sauce - Hollandaise',
#    'Soup - Campbells Tomato Ravioli',
#    'Dried Figs',
#    'Salmon - Sockeye Raw',
#    'Veal - Eye Of Round']},
#  {'CustomerID': 8917,
#   'Products': ['Lemonade - Natural, 591 Ml',
#    'Cod - Black Whole Fillet',
#    'Lamb - Pieces, Diced',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Cheese Cloth No 100']},
#  {'CustomerID': 8962,
#   'Products': ['Tofu - Firm',
#    'Beef - Chuck, Boneless',
#    'Fondant - Icing',
#    'Milk Powder',
#    'Foam Dinner Plate']},
#  {'CustomerID': 9047,
#   'Products': ['Pastry - Cheese Baked Scones',
#    'Lemonade - Natural, 591 Ml',
#    'Chinese Foods - Chicken',
#    'Turkey - Oven Roast Breast',
#    'Cheese - Wine']},
#  {'CustomerID': 9132,
#   'Products': ['Table Cloth 81x81 White',
#    'Sprouts - Baby Pea Tendrils',
#    'Wine - Blue Nun Qualitatswein',
#    'Bread - Raisin Walnut Oval',
#    'Pate - Cognac']},
#  {'CustomerID': 9260,
#   'Products': ['Wine - Pinot Noir Latour',
#    'Lime Cordial - Roses',
#    'Lamb - Pieces, Diced',
#    'Grouper - Fresh',
#    'Muffin - Zero Transfat']},
#  {'CustomerID': 9302,
#   'Products': ['Scallop - St. Jaques',
#    'Sausage - Breakfast',
#    'Vanilla Beans',
#    'Carbonated Water - Blackcherry',
#    'Puree - Passion Fruit']},
#  {'CustomerID': 9533,
#   'Products': ['Wine - Chardonnay South',
#    'Chicken - Wieners',
#    'Loquat',
#    'Mushroom - Porcini, Dry',
#    'Tea - Jasmin Green']},
#  {'CustomerID': 9546,
#   'Products': ['Olive - Spread Tapenade',
#    'Wine - Ej Gallo Sierra Valley',
#    'Pepper - Black, Whole',
#    'Longos - Grilled Chicken With',
#    'Salsify, Organic']},
#  {'CustomerID': 9597,
#   'Products': ['Wine - Chardonnay South',
#    'Cup - 6oz, Foam',
#    'Olives - Stuffed',
#    'Chicken - Leg, Boneless',
#    'Crush - Cream Soda']},
#  {'CustomerID': 9771,
#   'Products': ['Lettuce - California Mix',
#    'Pasta - Cheese / Spinach Bauletti',
#    'Cake - Mini Cheesecake',
#    'Wine - Magnotta - Belpaese',
#    'Thyme - Lemon, Fresh']},
#  {'CustomerID': 9804,
#   'Products': ['Foam Dinner Plate',
#    'Cup - Translucent 7 Oz Clear',
#    'Cheese - Bocconcini',
#    'Thyme - Lemon, Fresh',
#    'Vol Au Vents']},
#  {'CustomerID': 10016,
#   'Products': ['Veal - Inside, Choice',
#    'Pepper - White, Ground',
#    'Spinach - Baby',
#    'Cheese - Camembert',
#    'Cheese - Brie, Triple Creme']},
#  {'CustomerID': 10094,
#   'Products': ['Potatoes - Idaho 100 Count',
#    'Crackers - Trio',
#    'Cup - 6oz, Foam',
#    'Flour - Teff',
#    'General Purpose Trigger']},
#  {'CustomerID': 10114,
#   'Products': ['Turkey - Oven Roast Breast',
#    'Tart Shells - Sweet, 4',
#    'Wine - Blue Nun Qualitatswein',
#    'Crackers - Trio',
#    'Otomegusa Dashi Konbu']},
#  {'CustomerID': 10224,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Tea - English Breakfast',
#    'Skirt - 29 Foot',
#    'Langers - Ruby Red Grapfruit',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 10311,
#   'Products': ['Cod - Black Whole Fillet',
#    'Bandage - Flexible Neon',
#    'Cup - 6oz, Foam',
#    'Chicken - Soup Base',
#    'Soup V8 Roasted Red Pepper']},
#  {'CustomerID': 10418,
#   'Products': ['Thyme - Lemon, Fresh',
#    'Chips Potato All Dressed - 43g',
#    'Scallop - St. Jaques',
#    'Beef - Texas Style Burger',
#    'Zucchini - Yellow']},
#  {'CustomerID': 10739,
#   'Products': ['Pasta - Detalini, White, Fresh',
#    'Bar Mix - Pina Colada, 355 Ml',
#    'Pecan Raisin - Tarts',
#    'Wanton Wrap',
#    'Chicken - Soup Base']},
#  {'CustomerID': 11023,
#   'Products': ['Beans - Kidney White',
#    'Yoghurt Tubes',
#    'Dried Figs',
#    'Wanton Wrap',
#    'Bread - English Muffin']},
#  {'CustomerID': 11057,
#   'Products': ['Turkey - Oven Roast Breast',
#    'Quiche Assorted',
#    'Wine - Crozes Hermitage E.',
#    'Flour - Pastry',
#    'Foam Cup 6 Oz']},
#  {'CustomerID': 11083,
#   'Products': ['Milk - 2%',
#    'Wine - White, Colubia Cresh',
#    'Ketchup - Tomato',
#    'Jolt Cola - Electric Blue',
#    'Ecolab - Lime - A - Way 4/4 L']},
#  {'CustomerID': 11102,
#   'Products': ['Coffee - Hazelnut Cream',
#    'Rambutan',
#    'Rabbit - Whole',
#    'Coconut - Shredded, Sweet',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 11253,
#   'Products': ['Juice - Lime',
#    'Tomatoes Tear Drop',
#    'Pomello',
#    'Potatoes - Instant, Mashed',
#    'Table Cloth - 53x69 Colour']},
#  {'CustomerID': 11325,
#   'Products': ['Chicken - Leg, Boneless',
#    'Flour - Pastry',
#    'Remy Red',
#    'Lamb - Ground',
#    'Veal - Inside, Choice']},
#  {'CustomerID': 11380,
#   'Products': ['Rabbit - Whole',
#    'Sardines',
#    'Pecan Raisin - Tarts',
#    'Rambutan',
#    'Muffin Batt - Choc Chk']},
#  {'CustomerID': 11441,
#   'Products': ['Wine - Magnotta, Merlot Sr Vqa',
#    'Ice Cream Bar - Oreo Cone',
#    'Beef - Top Sirloin',
#    'Wine - Magnotta - Belpaese',
#    'Pop Shoppe Cream Soda']},
#  {'CustomerID': 11443,
#   'Products': ['Rabbit - Whole',
#    'Bay Leaf',
#    'Muffin - Zero Transfat',
#    'Wine - Pinot Noir Latour',
#    'Beef - Chuck, Boneless']},
#  {'CustomerID': 11614,
#   'Products': ['Cumin - Whole',
#    'Beans - Wax',
#    'Smirnoff Green Apple Twist',
#    'Sole - Dover, Whole, Fresh',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 11628,
#   'Products': ['Fuji Apples',
#    'Cheese - Cambozola',
#    'Flavouring - Orange',
#    'Rambutan',
#    'Gloves - Goldtouch Disposable']},
#  {'CustomerID': 11744,
#   'Products': ['Beef - Texas Style Burger',
#    'Beef - Ground Medium',
#    'Cocktail Napkin Blue',
#    'Cheese - Taleggio D.o.p.',
#    'Rice - Long Grain']},
#  {'CustomerID': 11883,
#   'Products': ['Doilies - 5, Paper',
#    'Hersey Shakes',
#    'Turkey - Oven Roast Breast',
#    'Kiwi',
#    'Soup Knorr Chili With Beans']},
#  {'CustomerID': 11933,
#   'Products': ['Lemonade - Natural, 591 Ml',
#    'Hersey Shakes',
#    'Curry Paste - Madras',
#    'Salsify, Organic',
#    'Sauerkraut']},
#  {'CustomerID': 12059,
#   'Products': ['Hinge W Undercut',
#    'Mushrooms - Black, Dried',
#    'Cod - Black Whole Fillet',
#    'Beef - Chuck, Boneless',
#    'Mayonnaise - Individual Pkg']},
#  {'CustomerID': 12206,
#   'Products': ['Bread - Hot Dog Buns',
#    'Ice Cream Bar - Hageen Daz To',
#    'Pasta - Orecchiette',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Knife Plastic - White']},
#  {'CustomerID': 12232,
#   'Products': ['Table Cloth 81x81 White',
#    'Beef - Texas Style Burger',
#    'Chestnuts - Whole,canned',
#    'Veal - Inside, Choice',
#    'Cheese - Mix']},
#  {'CustomerID': 12381,
#   'Products': ['Cheese - Parmesan Grated',
#    'Thyme - Lemon, Fresh',
#    'Soupfoamcont12oz 112con',
#    'Zucchini - Yellow',
#    'Onions - Cippolini']},
#  {'CustomerID': 12529,
#   'Products': ['Wine - Vineland Estate Semi - Dry',
#    'Spoon - Soup, Plastic',
#    'Mushroom - Porcini, Dry',
#    'Salmon - Sockeye Raw',
#    'Chicken - Leg, Boneless']},
#  {'CustomerID': 12561,
#   'Products': ['Pasta - Cheese / Spinach Bauletti',
#    'Ketchup - Tomato',
#    'Cocktail Napkin Blue',
#    'Wine - Magnotta - Belpaese',
#    'Rum - Mount Gay Eclipes']},
#  {'CustomerID': 12596,
#   'Products': ['Lettuce - Treviso',
#    'Bacardi Breezer - Tropical',
#    'Beef Ground Medium',
#    'Lamb - Pieces, Diced',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 12598,
#   'Products': ['Eggplant - Asian',
#    'Soupfoamcont12oz 112con',
#    'Beef - Short Loin',
#    'Spinach - Baby',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 12852,
#   'Products': ['Rice - Long Grain',
#    'Wine - Prosecco Valdobiaddene',
#    'Beef - Texas Style Burger',
#    'Crab - Imitation Flakes',
#    'Oil - Shortening - All - Purpose']},
#  {'CustomerID': 12888,
#   'Products': ['Grouper - Fresh',
#    'Cocoa Butter',
#    'Cocktail Napkin Blue',
#    'Ice Cream Bar - Hageen Daz To',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 13062,
#   'Products': ['Thermometer Digital',
#    'Wine - Blue Nun Qualitatswein',
#    'Knife Plastic - White',
#    'Pecan Raisin - Tarts',
#    'Bar Mix - Pina Colada, 355 Ml']},
#  {'CustomerID': 13118,
#   'Products': ['Wine - Magnotta, Merlot Sr Vqa',
#    'French Pastry - Mini Chocolate',
#    'Mushrooms - Black, Dried',
#    'Cheese - Brie,danish',
#    'Soup Knorr Chili With Beans']},
#  {'CustomerID': 13338,
#   'Products': ['Smirnoff Green Apple Twist',
#    'Bread - Hot Dog Buns',
#    'Watercress',
#    'Veal - Sweetbread',
#    'Sea Bass - Whole']},
#  {'CustomerID': 13354,
#   'Products': ['Carbonated Water - Cherry',
#    'Pork - Loin, Center Cut',
#    'Sauerkraut',
#    'Cod - Black Whole Fillet',
#    'Snapple - Iced Tea Peach']},
#  {'CustomerID': 13681,
#   'Products': ['Scallops - Live In Shell',
#    'Cheese - Taleggio D.o.p.',
#    'Curry Paste - Madras',
#    'Bread - Raisin Walnut Oval',
#    'Fuji Apples']},
#  {'CustomerID': 13699,
#   'Products': ['Sprouts - Baby Pea Tendrils',
#    'Tia Maria',
#    'Table Cloth 81x81 White',
#    'Pomello',
#    'Bread - Raisin Walnut Oval']},
#  {'CustomerID': 13823,
#   'Products': ['Cheese Cloth No 100',
#    'Pernod',
#    'Sauce - Demi Glace',
#    'Soup - Campbells Bean Medley',
#    'Mushrooms - Black, Dried']},
#  {'CustomerID': 13912,
#   'Products': ['Beef - Texas Style Burger',
#    'Rosemary - Dry',
#    'Tea - Jasmin Green',
#    'Pork - Loin, Center Cut',
#    'Cassis']},
#  {'CustomerID': 14012,
#   'Products': ['Soupcontfoam16oz 116con',
#    'Wine - Toasted Head',
#    'V8 - Berry Blend',
#    'Bay Leaf',
#    'Rambutan']},
#  {'CustomerID': 14208,
#   'Products': ['Pork - Loin, Center Cut',
#    'Chinese Foods - Chicken',
#    'Pomello',
#    'Sauce - Hollandaise',
#    'Sausage - Breakfast']},
#  {'CustomerID': 14501,
#   'Products': ['Skirt - 29 Foot',
#    'Cocktail Napkin Blue',
#    'Soupfoamcont12oz 112con',
#    'Muffin Mix - Blueberry',
#    'Lamb - Pieces, Diced']},
#  {'CustomerID': 14782,
#   'Products': ['Pork - Bacon, Double Smoked',
#    'Pomello',
#    'Beef Wellington',
#    'Juice - Lime',
#    'Skirt - 29 Foot']},
#  {'CustomerID': 14910,
#   'Products': ['Pie Filling - Cherry',
#    'Sauce - Hollandaise',
#    'Cheese - Boursin, Garlic / Herbs',
#    'Butter - Unsalted',
#    'Pork - Kidney']},
#  {'CustomerID': 14913,
#   'Products': ['French Pastry - Mini Chocolate',
#    'Wine - Crozes Hermitage E.',
#    'Cod - Black Whole Fillet',
#    'Cheese Cloth No 100',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 14977,
#   'Products': ['Bread - Italian Corn Meal Poly',
#    'Thyme - Lemon, Fresh',
#    'Lambcasing',
#    'Bread - Italian Roll With Herbs',
#    'Black Currants']},
#  {'CustomerID': 15027,
#   'Products': ['Pate - Cognac',
#    'Quiche Assorted',
#    'Sauerkraut',
#    'Bread Crumbs - Panko',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 15088,
#   'Products': ['Soup Knorr Chili With Beans',
#    'Soupfoamcont12oz 112con',
#    'Veal - Sweetbread',
#    'Cocktail Napkin Blue',
#    'Bread - Raisin Walnut Oval']},
#  {'CustomerID': 15119,
#   'Products': ['Curry Paste - Madras',
#    'Salsify, Organic',
#    'Hersey Shakes',
#    'Flour - Teff',
#    'Tahini Paste']},
#  {'CustomerID': 15148,
#   'Products': ['Wine - Gato Negro Cabernet',
#    'General Purpose Trigger',
#    'Chocolate - Dark',
#    'Butter - Unsalted',
#    'Bay Leaf']},
#  {'CustomerID': 15165,
#   'Products': ['Knife Plastic - White',
#    'Cheese - Mozzarella',
#    'Appetizer - Sausage Rolls',
#    'Sausage - Breakfast',
#    'Wine - Chardonnay South']},
#  {'CustomerID': 15166,
#   'Products': ['Lamb - Ground',
#    'Table Cloth 54x72 White',
#    'Pepper - Black, Whole',
#    'Mayonnaise - Individual Pkg',
#    'Soup - Campbells Tomato Ravioli']},
#  {'CustomerID': 15371,
#   'Products': ['Juice - Cranberry, 341 Ml',
#    'Hersey Shakes',
#    'Scallops - 10/20',
#    'Spoon - Soup, Plastic',
#    'Sausage - Breakfast']},
#  {'CustomerID': 15373,
#   'Products': ['Banana - Leaves',
#    'Milk - 2%',
#    'Muffin Mix - Blueberry',
#    'Sea Bass - Whole',
#    'Kellogs All Bran Bars']},
#  {'CustomerID': 15415,
#   'Products': ['Sauce - Hollandaise',
#    'Pork - Loin, Center Cut',
#    'Flavouring - Orange',
#    'Durian Fruit',
#    'Tea - Decaf Lipton']},
#  {'CustomerID': 15420,
#   'Products': ['Wine - Chardonnay South',
#    'Fenngreek Seed',
#    'Foam Dinner Plate',
#    'Bread - Italian Roll With Herbs',
#    'Gloves - Goldtouch Disposable']},
#  {'CustomerID': 15672,
#   'Products': ['Cheese - Cambozola',
#    'Cheese Cloth No 100',
#    'Rice - Long Grain',
#    'Scallops - 10/20',
#    'Crab - Imitation Flakes']},
#  {'CustomerID': 15796,
#   'Products': ['Table Cloth 81x81 White',
#    'Wine - Chardonnay South',
#    'Chocolate - Semi Sweet, Calets',
#    'Tea - Herbal Sweet Dreams',
#    'Tray - 16in Rnd Blk']},
#  {'CustomerID': 15851,
#   'Products': ['Beef - Ground Medium',
#    'Wine - Charddonnay Errazuriz',
#    'Sausage - Breakfast',
#    'Tomatoes Tear Drop',
#    'Tofu - Firm']},
#  {'CustomerID': 15888,
#   'Products': ['Sprouts - Baby Pea Tendrils',
#    'Wine - Chardonnay South',
#    'Chicken - Wieners',
#    'Salmon - Sockeye Raw',
#    'Pasta - Cheese / Spinach Bauletti']},
#  {'CustomerID': 15920,
#   'Products': ['Hersey Shakes',
#    'Grouper - Fresh',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Yogurt - French Vanilla',
#    'Wine - Red, Cooking']},
#  {'CustomerID': 15986,
#   'Products': ['Salsify, Organic',
#    'Smirnoff Green Apple Twist',
#    'Phyllo Dough',
#    'Cumin - Whole',
#    'Wine - Magnotta, Merlot Sr Vqa']},
#  {'CustomerID': 16139,
#   'Products': ['Cocktail Napkin Blue',
#    'Soup - Campbells Bean Medley',
#    'Soupfoamcont12oz 112con',
#    'Cheese - Wine',
#    'Wanton Wrap']},
#  {'CustomerID': 16375,
#   'Products': ['Mangoes',
#    'Beef - Chuck, Boneless',
#    'Wine - Red, Colio Cabernet',
#    'Rum - Mount Gay Eclipes',
#    'Sauce - Hollandaise']},
#  {'CustomerID': 16481,
#   'Products': ['Sausage - Breakfast',
#    'Chestnuts - Whole,canned',
#    'Mangoes',
#    'Loquat',
#    'Whmis - Spray Bottle Trigger']},
#  {'CustomerID': 16614,
#   'Products': ['Turkey - Oven Roast Breast',
#    'Spice - Peppercorn Melange',
#    'Cake - Mini Cheesecake',
#    'Rice - Long Grain',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 16650,
#   'Products': ['Cheese - Parmesan Grated',
#    'V8 - Berry Blend',
#    'Spinach - Baby',
#    'Banana - Leaves',
#    'Milk - 2%']},
#  {'CustomerID': 16664,
#   'Products': ['Loquat',
#    'Wine - Hardys Bankside Shiraz',
#    'Bread Crumbs - Japanese Style',
#    'Table Cloth 81x81 White',
#    'Foam Dinner Plate']},
#  {'CustomerID': 16809,
#   'Products': ['Pomello',
#    'Sausage - Breakfast',
#    'Table Cloth 62x114 White',
#    'Halibut - Steaks',
#    'Soup - Campbells Tomato Ravioli']},
#  {'CustomerID': 16971,
#   'Products': ['Spice - Peppercorn Melange',
#    'Milk - 2%',
#    'Foam Dinner Plate',
#    'Jolt Cola - Electric Blue',
#    'Island Oasis - Mango Daiquiri']},
#  {'CustomerID': 16997,
#   'Products': ['Mayonnaise - Individual Pkg',
#    'Flour - Pastry',
#    'Sausage - Breakfast',
#    'Scallop - St. Jaques',
#    'Cheese - Camembert']},
#  {'CustomerID': 17097,
#   'Products': ['Ketchup - Tomato',
#    'Wine - Crozes Hermitage E.',
#    'Sprouts - Alfalfa',
#    'Flour - Teff',
#    'Pastry - Choclate Baked']},
#  {'CustomerID': 17136,
#   'Products': ['Cocktail Napkin Blue',
#    'Soupfoamcont12oz 112con',
#    'Sugar - Fine',
#    'Wine - Two Oceans Cabernet',
#    'Foam Dinner Plate']},
#  {'CustomerID': 17263,
#   'Products': ['Chinese Foods - Chicken',
#    'General Purpose Trigger',
#    'Bread - Italian Corn Meal Poly',
#    'Ice Cream Bar - Hageen Daz To',
#    'Scallops - 10/20']},
#  {'CustomerID': 17390,
#   'Products': ['Pasta - Penne, Rigate, Dry',
#    'Coffee - Hazelnut Cream',
#    'Soup Knorr Chili With Beans',
#    'Sardines',
#    'Chicken - Leg, Boneless']},
#  {'CustomerID': 17404,
#   'Products': ['Isomalt',
#    'Cheese - Mix',
#    'Thyme - Lemon, Fresh',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Potatoes - Instant, Mashed']},
#  {'CustomerID': 17407,
#   'Products': ['Lamb - Ground',
#    'Sauerkraut',
#    'Bread - Italian Roll With Herbs',
#    'Scallops - 10/20',
#    'Langers - Ruby Red Grapfruit']},
#  {'CustomerID': 17458,
#   'Products': ['Chinese Foods - Chicken',
#    'Lettuce - Treviso',
#    'Lamb - Pieces, Diced',
#    'Wine - Blue Nun Qualitatswein',
#    'Watercress']},
#  {'CustomerID': 17472,
#   'Products': ['Cookie Chocolate Chip With',
#    'Foam Cup 6 Oz',
#    'Yogurt - Blueberry, 175 Gr',
#    'Bread - French Baquette',
#    'Sobe - Tropical Energy']},
#  {'CustomerID': 17760,
#   'Products': ['Oranges - Navel, 72',
#    'V8 - Berry Blend',
#    'Nut - Pistachio, Shelled',
#    'Tahini Paste',
#    'Tea - Jasmin Green']},
#  {'CustomerID': 17765,
#   'Products': ['Tomatoes Tear Drop',
#    'Juice - Cranberry, 341 Ml',
#    'Lamb - Ground',
#    'Foam Dinner Plate',
#    'Dc - Frozen Momji']},
#  {'CustomerID': 17906,
#   'Products': ['Cheese - Parmesan Grated',
#    'Appetizer - Sausage Rolls',
#    'Beef - Chuck, Boneless',
#    'Cake - Mini Cheesecake',
#    'Bread - Hot Dog Buns']},
#  {'CustomerID': 18027,
#   'Products': ['Chocolate - Dark',
#    'Bread - Italian Corn Meal Poly',
#    'Soup - Campbells Bean Medley',
#    'Cheese Cloth No 100',
#    'Wanton Wrap']},
#  {'CustomerID': 18040,
#   'Products': ['Nut - Pistachio, Shelled',
#    'Cheese - Parmesan Cubes',
#    'Watercress',
#    'Wanton Wrap',
#    'Sausage - Breakfast']},
#  {'CustomerID': 18133,
#   'Products': ['Lamb - Ground',
#    'Loquat',
#    'Beets - Mini Golden',
#    'Tahini Paste',
#    'Flour - Pastry']},
#  {'CustomerID': 18281,
#   'Products': ['Raspberries - Fresh',
#    'Hersey Shakes',
#    'Sausage - Breakfast',
#    'Veal - Sweetbread',
#    'Cheese - Parmesan Grated']},
#  {'CustomerID': 18293,
#   'Products': ['Beef - Texas Style Burger',
#    'Foam Cup 6 Oz',
#    'Rum - Coconut, Malibu',
#    'Olives - Kalamata',
#    'Soup V8 Roasted Red Pepper']},
#  {'CustomerID': 18364,
#   'Products': ['Beef - Texas Style Burger',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Spoon - Soup, Plastic',
#    'Veal - Sweetbread',
#    'Hersey Shakes']},
#  {'CustomerID': 18441,
#   'Products': ['Soupfoamcont12oz 112con',
#    'Anchovy Paste - 56 G Tube',
#    'Sprouts - Baby Pea Tendrils',
#    'Lemonade - Natural, 591 Ml',
#    'Sausage - Breakfast']},
#  {'CustomerID': 18480,
#   'Products': ['Cheese - Mozzarella',
#    'Bread - Rye',
#    'Pork - Loin, Center Cut',
#    'Water, Tap',
#    'Fenngreek Seed']},
#  {'CustomerID': 18552,
#   'Products': ['Tea - Jasmin Green',
#    'Coffee - Dark Roast',
#    'Ezy Change Mophandle',
#    'Cake - Mini Cheesecake',
#    'Foam Dinner Plate']},
#  {'CustomerID': 18591,
#   'Products': ['Cocktail Napkin Blue',
#    'Mushrooms - Black, Dried',
#    'Pasta - Cheese / Spinach Bauletti',
#    'Raspberries - Fresh',
#    'Berry Brulee']},
#  {'CustomerID': 18622,
#   'Products': ['Soup - Campbells Bean Medley',
#    'Cheese Cloth No 100',
#    'Potatoes - Idaho 100 Count',
#    'Smoked Paprika',
#    'Bread - Hot Dog Buns']},
#  {'CustomerID': 18680,
#   'Products': ['Chocolate - Dark',
#    'Cheese - Cheddarsliced',
#    'Lettuce - Spring Mix',
#    'Cheese - Parmesan Grated',
#    'Sauce - Hollandaise']},
#  {'CustomerID': 18683,
#   'Products': ['Salsify, Organic',
#    'Veal - Eye Of Round',
#    'Beef - Chuck, Boneless',
#    'Potatoes - Instant, Mashed',
#    'Mangoes']},
#  {'CustomerID': 18688,
#   'Products': ['Pork - Loin, Center Cut',
#    'Chocolate - Compound Coating',
#    'Pomello',
#    'Bread - Raisin Walnut Oval',
#    'Pail For Lid 1537']},
#  {'CustomerID': 18706,
#   'Products': ['Spice - Peppercorn Melange',
#    'Curry Paste - Madras',
#    'Cod - Black Whole Fillet',
#    'Beans - Wax',
#    'Bread - Raisin Walnut Oval']},
#  {'CustomerID': 18720,
#   'Products': ['Coffee - Hazelnut Cream',
#    'Chicken - Leg, Boneless',
#    'Tea - Jasmin Green',
#    'Kiwi',
#    'Ocean Spray - Kiwi Strawberry']},
#  {'CustomerID': 18728,
#   'Products': ['Yogurt - French Vanilla',
#    'Quiche Assorted',
#    'Fondant - Icing',
#    'Wine - Gato Negro Cabernet',
#    'Soup - Campbells Bean Medley']},
#  {'CustomerID': 18760,
#   'Products': ['Chocolate - Compound Coating',
#    'Grouper - Fresh',
#    'Mangoes',
#    'Black Currants',
#    'Orange - Canned, Mandarin']},
#  {'CustomerID': 18796,
#   'Products': ['Crackers - Trio',
#    'Nut - Pistachio, Shelled',
#    'Knife Plastic - White',
#    'Bread - Italian Roll With Herbs',
#    'Liners - Banana, Paper']},
#  {'CustomerID': 19074,
#   'Products': ['Cheese - Mozzarella',
#    'Raspberries - Fresh',
#    'Tea - Decaf Lipton',
#    'Cheese - Cottage Cheese',
#    'Table Cloth 81x81 White']},
#  {'CustomerID': 19147,
#   'Products': ['Beer - Sleemans Cream Ale',
#    'Table Cloth 54x72 White',
#    'Bread - Raisin Walnut Oval',
#    'Butter - Unsalted',
#    'Yoghurt Tubes']},
#  {'CustomerID': 19148,
#   'Products': ['Chicken - Leg, Boneless',
#    'Olives - Stuffed',
#    'Pop Shoppe Cream Soda',
#    'Wine - Prosecco Valdobiaddene',
#    'Tahini Paste']},
#  {'CustomerID': 19260,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Cheese - Mozzarella',
#    'Pork - Loin, Center Cut',
#    'Pasta - Penne, Rigate, Dry',
#    'Tea - Jasmin Green']},
#  {'CustomerID': 19312,
#   'Products': ['Wine - Sogrape Mateus Rose',
#    'Salsify, Organic',
#    'Foam Cup 6 Oz',
#    'Cheese - Parmesan Grated',
#    'Cod - Black Whole Fillet']},
#  {'CustomerID': 19442,
#   'Products': ['Cod - Black Whole Fillet',
#    'Kellogs Special K Cereal',
#    'Carbonated Water - Cherry',
#    'Mushroom - Trumpet, Dry',
#    'Nantuket Peach Orange']},
#  {'CustomerID': 19526,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Lettuce - Spring Mix',
#    'Chocolate - Dark',
#    'Cocktail Napkin Blue',
#    'Mushrooms - Black, Dried']},
#  {'CustomerID': 19753,
#   'Products': ['Cake - Mini Cheesecake',
#    'Jolt Cola - Electric Blue',
#    'Coffee - Dark Roast',
#    'Juice - Lime',
#    'Pork - Bacon, Double Smoked']},
#  {'CustomerID': 20006,
#   'Products': ['Curry Paste - Madras',
#    'Placemat - Scallop, White',
#    'Sauerkraut',
#    'Salsify, Organic',
#    'Onions - Cippolini']},
#  {'CustomerID': 20125,
#   'Products': ['Beef Ground Medium',
#    'Beer - Original Organic Lager',
#    'Soup V8 Roasted Red Pepper',
#    'Bread - Rye',
#    'Lamb - Ground']},
#  {'CustomerID': 20134,
#   'Products': ['Cheese - Mozzarella',
#    'Cheese - Cottage Cheese',
#    'Beer - Sleemans Cream Ale',
#    'Beef - Short Loin',
#    'Wine - Chardonnay South']},
#  {'CustomerID': 20331,
#   'Products': ['Ketchup - Tomato',
#    'Spoon - Soup, Plastic',
#    'Lime Cordial - Roses',
#    'Pop Shoppe Cream Soda',
#    'Scallops - 10/20']},
#  {'CustomerID': 20433,
#   'Products': ['Mustard Prepared',
#    'Cheese - Camembert',
#    'Crackers Cheez It',
#    'Broom - Corn',
#    'Scallop - St. Jaques']},
#  {'CustomerID': 20446,
#   'Products': ['Beans - Kidney, Canned',
#    'Rice - Long Grain',
#    'Quiche Assorted',
#    'Turkey - Oven Roast Breast',
#    'Pie Filling - Cherry']},
#  {'CustomerID': 20476,
#   'Products': ['Soup - Campbells Tomato Ravioli',
#    'Pasta - Detalini, White, Fresh',
#    'Cheese - Boursin, Garlic / Herbs',
#    'Beans - Kidney White',
#    'Wine - Blue Nun Qualitatswein']},
#  {'CustomerID': 20648,
#   'Products': ['Yoghurt Tubes',
#    'Tray - 16in Rnd Blk',
#    'Halibut - Steaks',
#    'Berry Brulee',
#    'Beef - Chuck, Boneless']},
#  {'CustomerID': 20901,
#   'Products': ['Bread Crumbs - Panko',
#    'Table Cloth 62x114 White',
#    'Wiberg Super Cure',
#    'Puree - Passion Fruit',
#    'Appetizer - Sausage Rolls']},
#  {'CustomerID': 20907,
#   'Products': ['Beef - Ground Medium',
#    'Lamb - Ground',
#    'Lamb - Whole, Fresh',
#    'Sauce - Rosee',
#    'Cinnamon Buns Sticky']},
#  {'CustomerID': 21027,
#   'Products': ['Pork - Back, Short Cut, Boneless',
#    'Potatoes - Idaho 100 Count',
#    'Spoon - Soup, Plastic',
#    'Wine - Chardonnay South',
#    'Chinese Foods - Chicken']},
#  {'CustomerID': 21095,
#   'Products': ['Rice - Long Grain',
#    'Bread - Calabrese Baguette',
#    'Pork - Back, Short Cut, Boneless',
#    'Rabbit - Whole',
#    'Milk Powder']},
#  {'CustomerID': 21177,
#   'Products': ['Hersey Shakes',
#    'Scallops - Live In Shell',
#    'Halibut - Steaks',
#    'Tea - Jasmin Green',
#    'Onions - Cippolini']},
#  {'CustomerID': 21734,
#   'Products': ['Pork - Loin, Center Cut',
#    'Lamb - Ground',
#    'V8 - Berry Blend',
#    'Lettuce - Treviso',
#    'Beef - Tenderlion, Center Cut']},
#  {'CustomerID': 21795,
#   'Products': ['Soup - Campbells Tomato Ravioli',
#    'Lambcasing',
#    'Ketchup - Tomato',
#    'Beef - Top Sirloin',
#    'Macaroons - Two Bite Choc']},
#  {'CustomerID': 21973,
#   'Products': ['Watercress',
#    'Salmon - Sockeye Raw',
#    'Flour - Pastry',
#    'Cod - Black Whole Fillet',
#    'Cumin - Whole']},
#  {'CustomerID': 22175,
#   'Products': ['Cake - Cake Sheet Macaroon',
#    'Chef Hat 20cm',
#    'Table Cloth 81x81 White',
#    'Muffin - Carrot Individual Wrap',
#    'Mussels - Frozen']},
#  {'CustomerID': 22204,
#   'Products': ['Loquat',
#    'Foam Dinner Plate',
#    'Wine - Magnotta, Merlot Sr Vqa',
#    'Chicken - Leg, Boneless',
#    'General Purpose Trigger']},
#  {'CustomerID': 22308,
#   'Products': ['Appetizer - Mushroom Tart',
#    'Bread - Roll, Canadian Dinner',
#    'Seedlings - Mix, Organic',
#    'Pepper - Black, Whole',
#    'Muffin Batt - Blueberry Passion']},
#  {'CustomerID': 22322,
#   'Products': ['Scallop - St. Jaques',
#    'Muffin - Carrot Individual Wrap',
#    'General Purpose Trigger',
#    'Juice - Apple Cider',
#    'Doilies - 5, Paper']},
#  {'CustomerID': 22345,
#   'Products': ['Olives - Kalamata',
#    'Juice - Apple Cider',
#    'Pate - Cognac',
#    'Bread - Raisin Walnut Oval',
#    'Cheese Cloth No 100']},
#  {'CustomerID': 22408,
#   'Products': ['Beans - Wax',
#    'Muffin Mix - Blueberry',
#    'Hersey Shakes',
#    'Juice - V8 Splash',
#    'Nut - Chestnuts, Whole']},
#  {'CustomerID': 22454,
#   'Products': ['Spinach - Baby',
#    'Beer - Labatt Blue',
#    'Knife Plastic - White',
#    'Garlic - Peeled',
#    'Soupcontfoam16oz 116con']},
#  {'CustomerID': 22461,
#   'Products': ['Salsify, Organic',
#    'Apricots - Halves',
#    'Ezy Change Mophandle',
#    'Beer - Original Organic Lager',
#    'Tofu - Firm']},
#  {'CustomerID': 22508,
#   'Products': ['Beef - Chuck, Boneless',
#    'Chef Hat 20cm',
#    'Muffin Batt - Choc Chk',
#    'Ecolab - Solid Fusion',
#    'Muffin Mix - Blueberry']},
#  {'CustomerID': 22536,
#   'Products': ['Bacardi Breezer - Tropical',
#    'Cheese - Mozzarella',
#    'Cheese Cloth No 100',
#    'Bread - Italian Roll With Herbs',
#    'Bread - Hot Dog Buns']},
#  {'CustomerID': 22705,
#   'Products': ['Sausage - Breakfast',
#    'Scallop - St. Jaques',
#    'Nut - Pistachio, Shelled',
#    'Muffin Batt - Choc Chk',
#    'Rum - Coconut, Malibu']},
#  {'CustomerID': 22751,
#   'Products': ['Olive - Spread Tapenade',
#    'Wine - Chardonnay South',
#    'Lettuce - Treviso',
#    'Knife Plastic - White',
#    'Cheese - Cottage Cheese']},
#  {'CustomerID': 22901,
#   'Products': ['Watercress',
#    'Mussels - Frozen',
#    'Mangoes',
#    'Cumin - Whole',
#    'Muffin Batt - Choc Chk']},
#  {'CustomerID': 22939,
#   'Products': ['Muffin Batt - Choc Chk',
#    'Rambutan',
#    'Ecolab - Solid Fusion',
#    'Pepper - Paprika, Hungarian',
#    'Crackers - Trio']},
#  {'CustomerID': 22982,
#   'Products': ['Chinese Foods - Chicken',
#    'Bouq All Italian - Primerba',
#    'Bar - Granola Trail Mix Fruit Nut',
#    'Cup - 6oz, Foam',
#    'Vinegar - Tarragon']},
#  {'CustomerID': 23001,
#   'Products': ['Langers - Ruby Red Grapfruit',
#    'Sauce - Demi Glace',
#    'Spoon - Soup, Plastic',
#    'Foam Dinner Plate',
#    'Rice - Long Grain']},
#  {'CustomerID': 23165,
#   'Products': ['Quiche Assorted',
#    'Beef - Striploin Aa',
#    'Tahini Paste',
#    'Crush - Cream Soda',
#    'Olives - Kalamata']},
#  {'CustomerID': 23176,
#   'Products': ['Doilies - 5, Paper',
#    'Sunflower Seed Raw',
#    'Bread - Hot Dog Buns',
#    'Nantuket Peach Orange',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 23220,
#   'Products': ['Black Currants',
#    'Beef Wellington',
#    'Crab - Dungeness, Whole',
#    'Fish - Scallops, Cold Smoked',
#    'Bread - Rye']},
#  {'CustomerID': 23377,
#   'Products': ['Watercress',
#    'Mussels - Frozen',
#    'Scampi Tail',
#    'Beans - Kidney, Canned',
#    'Cumin - Whole']},
#  {'CustomerID': 23451,
#   'Products': ['Yoghurt Tubes',
#    'Cumin - Whole',
#    'Watercress',
#    'Flour - Teff',
#    'Chicken - Wieners']},
#  {'CustomerID': 23515,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Milk - 1%',
#    'Beef - Short Loin',
#    'Scallops - Live In Shell',
#    'Isomalt']},
#  {'CustomerID': 23548,
#   'Products': ['Squid - Tubes / Tenticles 10/20',
#    'Sprouts - Baby Pea Tendrils',
#    'Flavouring - Orange',
#    'Bread - Raisin Walnut Oval',
#    'Banana Turning']},
#  {'CustomerID': 24137,
#   'Products': ['Cheese - Mozzarella',
#    'Cheese - Wine',
#    'Bread - Raisin Walnut Oval',
#    'Salsify, Organic',
#    'Pork - Kidney']},
#  {'CustomerID': 24271,
#   'Products': ['Cake - Cake Sheet Macaroon',
#    'Wine - Ej Gallo Sierra Valley',
#    'Thermometer Digital',
#    'Garbage Bags - Clear',
#    'Shrimp - 31/40']},
#  {'CustomerID': 24323,
#   'Products': ['General Purpose Trigger',
#    'Scallop - St. Jaques',
#    'Sausage - Breakfast',
#    'Lamb - Ground',
#    'Bacardi Breezer - Tropical']},
#  {'CustomerID': 24435,
#   'Products': ['Arizona - Green Tea',
#    'Water - Mineral, Natural',
#    'Cake - Box Window 10x10x2.5',
#    'Dried Figs',
#    'Sugar - Fine']},
#  {'CustomerID': 24490,
#   'Products': ['Potatoes - Idaho 100 Count',
#    'Bananas',
#    'Beef - Tenderlion, Center Cut',
#    'Wine - Crozes Hermitage E.',
#    'Wine - Chardonnay South']},
#  {'CustomerID': 24554,
#   'Products': ['Soup - Campbells, Beef Barley',
#    'Beef - Chuck, Boneless',
#    'Tahini Paste',
#    'Chicken - Leg, Boneless',
#    'Ezy Change Mophandle']},
#  {'CustomerID': 24820,
#   'Products': ['Beef - Chuck, Boneless',
#    'Salsify, Organic',
#    'Beer - Sleemans Cream Ale',
#    'Coconut - Shredded, Sweet',
#    'Cake - Mini Cheesecake']},
#  {'CustomerID': 25013,
#   'Products': ['Veal - Inside, Choice',
#    'Mangoes',
#    'Beef - Chuck, Boneless',
#    'Nut - Chestnuts, Whole',
#    'Halibut - Fletches']},
#  {'CustomerID': 25040,
#   'Products': ['Tahini Paste',
#    'Skirt - 29 Foot',
#    'Bread - Italian Roll With Herbs',
#    'Beets - Mini Golden',
#    'Nut - Pistachio, Shelled']},
#  {'CustomerID': 25125,
#   'Products': ['Tea - Earl Grey',
#    'Thermometer Digital',
#    'Snapple Lemon Tea',
#    'Bandage - Flexible Neon',
#    'Beef - Ground Medium']},
#  {'CustomerID': 25209,
#   'Products': ['Beer - Original Organic Lager',
#    'Spoon - Soup, Plastic',
#    'Lamb - Ground',
#    'Cheese - Boursin, Garlic / Herbs',
#    'Muffin - Carrot Individual Wrap']},
#  {'CustomerID': 25270,
#   'Products': ['Beef - Top Sirloin',
#    'Grouper - Fresh',
#    'Soup Knorr Chili With Beans',
#    'Eggplant - Asian',
#    'Lime Cordial - Roses']},
#  {'CustomerID': 25292,
#   'Products': ['Wine - Chardonnay South',
#    'Sausage - Breakfast',
#    'Banana Turning',
#    'Spinach - Baby',
#    'Pork - Kidney']},
#  {'CustomerID': 25327,
#   'Products': ['Juice - Cranberry, 341 Ml',
#    'Eggplant - Asian',
#    'Scallops - Live In Shell',
#    'Hinge W Undercut',
#    'Halibut - Steaks']},
#  {'CustomerID': 25420,
#   'Products': ['Wine - Valpolicella Masi',
#    'Lemonade - Natural, 591 Ml',
#    'Lime Cordial - Roses',
#    'Sherry - Dry',
#    'Phyllo Dough']},
#  {'CustomerID': 25421,
#   'Products': ['Smirnoff Green Apple Twist',
#    'Tofu - Firm',
#    'Oranges - Navel, 72',
#    'Beef - Ground Medium',
#    'Wine - Charddonnay Errazuriz']},
#  {'CustomerID': 25449,
#   'Products': ['Crab - Dungeness, Whole',
#    'Lime Cordial - Roses',
#    'Pate - Cognac',
#    'Beer - Blue',
#    'Wine - Red, Harrow Estates, Cab']},
#  {'CustomerID': 25624,
#   'Products': ['Lettuce - Spring Mix',
#    'Salmon Steak - Cohoe 8 Oz',
#    'Napkin White - Starched',
#    'Wine - Blue Nun Qualitatswein',
#    'Sea Bass - Whole']},
#  {'CustomerID': 25651,
#   'Products': ['Bandage - Flexible Neon',
#    'Wine - Hardys Bankside Shiraz',
#    'Scallops - Live In Shell',
#    'Milk Powder',
#    'Rum - Coconut, Malibu']},
#  {'CustomerID': 25703,
#   'Products': ['Guinea Fowl',
#    'Apricots - Halves',
#    'Duck - Breast',
#    'Cheese - Boursin, Garlic / Herbs',
#    'Ketchup - Tomato']},
#  {'CustomerID': 25779,
#   'Products': ['Beef - Top Sirloin',
#    'Coconut - Shredded, Sweet',
#    'Longos - Grilled Chicken With',
#    'Quiche Assorted',
#    'Potatoes - Idaho 100 Count']},
# ...
#    'Beer - Labatt Blue',
#    'Chicken - Leg, Boneless']},
#  {'CustomerID': 89272,
#   'Products': ['Blueberries',
#    'Pastry - Choclate Baked',
#    'Oregano - Dry, Rubbed',
#    'Olives - Kalamata',
#    'Bread - Multigrain']},
#  {'CustomerID': 89408,
#   'Products': ['Wine - Chablis 2003 Champs',
#    'Napkin White - Starched',
#    'Hot Chocolate - Individual',
#    'Hickory Smoke, Liquid',
#    'Pail With Metal Handle 16l White']},
#  {'CustomerID': 89424,
#   'Products': ['Lamb - Whole, Fresh',
#    'Beef - Prime Rib Aaa',
#    'Steam Pan - Half Size Deep',
#    'Cocoa Butter',
#    'Sauerkraut']},
#  {'CustomerID': 89425,
#   'Products': ['Tart Shells - Sweet, 4',
#    'Cheese - Cottage Cheese',
#    'Cheese - Taleggio D.o.p.',
#    'Cocoa Butter',
#    'Cheese - Cheddarsliced']},
#  {'CustomerID': 89573,
#   'Products': ['Bread - Raisin Walnut Oval',
#    'Soup Campbells - Italian Wedding',
#    'Crab - Imitation Flakes',
#    'Beans - Kidney White',
#    'Shrimp - Baby, Warm Water']},
#  {'CustomerID': 89588,
#   'Products': ['Cheese - Parmesan Cubes',
#    'Napkin White - Starched',
#    'Kellogs Special K Cereal',
#    'Wasabi Powder',
#    'Cassis']},
#  {'CustomerID': 89725,
#   'Products': ['Bread - Multigrain',
#    'Wine - Charddonnay Errazuriz',
#    'Lentils - Red, Dry',
#    'Tofu - Firm',
#    'Cheese - Brie,danish']},
#  {'CustomerID': 90054,
#   'Products': ['Wine - Ruffino Chianti',
#    'Carbonated Water - Cherry',
#    'Pastry - Butterscotch Baked',
#    'Beets - Candy Cane, Organic',
#    'Beets - Mini Golden']},
#  {'CustomerID': 90069,
#   'Products': ['Pastry - Butterscotch Baked',
#    'Doilies - 5, Paper',
#    'Crackers - Trio',
#    'Wine - Charddonnay Errazuriz',
#    'Rice - Jasmine Sented']},
#  {'CustomerID': 90174,
#   'Products': ['Wine - White Cab Sauv.on',
#    'Seedlings - Mix, Organic',
#    'Scallops 60/80 Iqf',
#    'Kellogs All Bran Bars',
#    'Beer - Alexander Kieths, Pale Ale']},
#  {'CustomerID': 90193,
#   'Products': ['Doilies - 5, Paper',
#    'Table Cloth 81x81 White',
#    'Sauce - Demi Glace',
#    'Cinnamon Buns Sticky',
#    'Grapes - Red']},
#  {'CustomerID': 90284,
#   'Products': ['Wine - Chardonnay South',
#    'Squid - Tubes / Tenticles 10/20',
#    'Cumin - Whole',
#    'Rice - Jasmine Sented',
#    'Flour - Whole Wheat']},
#  {'CustomerID': 90300,
#   'Products': ['Scallops - Live In Shell',
#    'Chicken - Soup Base',
#    'Veal - Inside',
#    'Pepper - Paprika, Hungarian',
#    'Puree - Mocha']},
#  {'CustomerID': 90347,
#   'Products': ['Lettuce - Treviso',
#    'Apricots - Dried',
#    'Beef - Montreal Smoked Brisket',
#    'Anchovy Paste - 56 G Tube',
#    'Blueberries']},
#  {'CustomerID': 90508,
#   'Products': ['Ice Cream Bar - Hageen Daz To',
#    'Tray - 16in Rnd Blk',
#    'Beets - Mini Golden',
#    'Beer - Original Organic Lager',
#    'Baking Powder']},
#  {'CustomerID': 90694,
#   'Products': ['Table Cloth - 53x69 Colour',
#    'Apricots - Dried',
#    'Wasabi Powder',
#    'Wine - Red, Colio Cabernet',
#    'Beef - Ground, Extra Lean, Fresh']},
#  {'CustomerID': 90776,
#   'Products': ['Cocktail Napkin Blue',
#    'Pickerel - Fillets',
#    'Ice Cream Bar - Drumstick',
#    'Sun - Dried Tomatoes',
#    'Sobe - Tropical Energy']},
#  {'CustomerID': 90777,
#   'Products': ['Sole - Dover, Whole, Fresh',
#    'Foam Dinner Plate',
#    'Chicken - Leg, Boneless',
#    'Vinegar - Tarragon',
#    'Cheese - Wine']},
#  {'CustomerID': 90933,
#   'Products': ['Bread - Multigrain',
#    'Lamb - Pieces, Diced',
#    'Browning Caramel Glace',
#    'Dc - Frozen Momji',
#    'Vol Au Vents']},
#  {'CustomerID': 91013,
#   'Products': ['Water - Spring Water 500ml',
#    'Beef - Top Sirloin - Aaa',
#    'Tofu - Firm',
#    'Chips Potato Salt Vinegar 43g',
#    'Tray - 16in Rnd Blk']},
#  {'CustomerID': 91058,
#   'Products': ['Garbage Bags - Clear',
#    'Cocoa Butter',
#    'Crackers - Trio',
#    'Kiwi',
#    'Thermometer Digital']},
#  {'CustomerID': 91176,
#   'Products': ['Towels - Paper / Kraft',
#    'Baking Powder',
#    'Coffee - Irish Cream',
#    'Tray - 16in Rnd Blk',
#    'Wine - Ruffino Chianti']},
#  {'CustomerID': 91194,
#   'Products': ['Bread Fig And Almond',
#    'Water - Aquafina Vitamin',
#    'Halibut - Fletches',
#    'Onions - Vidalia',
#    'Lettuce - California Mix']},
#  {'CustomerID': 91220,
#   'Products': ['Bread - Italian Corn Meal Poly',
#    'Chocolate - Compound Coating',
#    'Tomato - Tricolor Cherry',
#    'Cheese - Boursin, Garlic / Herbs',
#    'Bread - Calabrese Baguette']},
#  {'CustomerID': 91224,
#   'Products': ['Wine - White, Colubia Cresh',
#    'Beef - Top Sirloin - Aaa',
#    'Scallops - Live In Shell',
#    'Veal - Sweetbread',
#    'Isomalt']},
#  {'CustomerID': 91443,
#   'Products': ['Cheese - Cottage Cheese',
#    'Wine - White, Schroder And Schyl',
#    'Berry Brulee',
#    'Cheese - Brie,danish',
#    'Nantuket Peach Orange']},
#  {'CustomerID': 91652,
#   'Products': ['Pasta - Penne, Rigate, Dry',
#    'Yogurt - French Vanilla',
#    'Beef - Short Loin',
#    'Wiberg Super Cure',
#    'Scallops 60/80 Iqf']},
#  {'CustomerID': 91713,
#   'Products': ['Pears - Bosc',
#    'Shrimp - 31/40',
#    'Appetizer - Mushroom Tart',
#    'Cocoa Butter',
#    'Wine - Red, Harrow Estates, Cab']},
#  {'CustomerID': 91777,
#   'Products': ['Wine - Redchard Merritt',
#    'Flour - Teff',
#    'Lentils - Red, Dry',
#    'Fenngreek Seed',
#    'Water, Tap']},
#  {'CustomerID': 91783,
#   'Products': ['Sea Bass - Whole',
#    'Apricots - Halves',
#    'Watercress',
#    'Onion Powder',
#    'Sausage - Breakfast']},
#  {'CustomerID': 92067,
#   'Products': ['Bandage - Flexible Neon',
#    'Yoghurt Tubes',
#    'Beef - Inside Round',
#    'Scallops 60/80 Iqf',
#    'Cheese - Mozzarella']},
#  {'CustomerID': 92139,
#   'Products': ['Soup Knorr Chili With Beans',
#    'Skirt - 29 Foot',
#    'Cookie Chocolate Chip With',
#    'V8 - Berry Blend',
#    'Foam Dinner Plate']},
#  {'CustomerID': 92168,
#   'Products': ['Cup - Translucent 7 Oz Clear',
#    'Veal - Brisket, Provimi,bnls',
#    'Snapple Lemon Tea',
#    'Spinach - Baby',
#    'Pop Shoppe Cream Soda']},
#  {'CustomerID': 92255,
#   'Products': ['Pastry - Choclate Baked',
#    'Pop Shoppe Cream Soda',
#    'Mussels - Cultivated',
#    'Cup - Translucent 7 Oz Clear',
#    'Bouq All Italian - Primerba']},
#  {'CustomerID': 92418,
#   'Products': ['Initation Crab Meat',
#    'Oregano - Dry, Rubbed',
#    'Vinegar - Sherry',
#    'Soup - Campbells, Lentil',
#    'Pomello']},
#  {'CustomerID': 92492,
#   'Products': ['Crackers - Trio',
#    'Vaccum Bag 10x13',
#    'Beef - Inside Round',
#    'Nantuket Peach Orange',
#    'Placemat - Scallop, White']},
#  {'CustomerID': 92525,
#   'Products': ['Cocktail Napkin Blue',
#    'Beef - Ground, Extra Lean, Fresh',
#    'Beef - Striploin Aa',
#    'Bread - Roll, Soft White Round',
#    'Chestnuts - Whole,canned']},
#  {'CustomerID': 92543,
#   'Products': ['Beef - Tenderlion, Center Cut',
#    'Puree - Passion Fruit',
#    'Bananas',
#    'Table Cloth 81x81 White',
#    'Potatoes - Idaho 100 Count']},
#  {'CustomerID': 92594,
#   'Products': ['Beef - Striploin Aa',
#    'Apricots - Dried',
#    'Brandy - Bar',
#    'Beef - Inside Round',
#    'Oil - Shortening - All - Purpose']},
#  {'CustomerID': 92637,
#   'Products': ['Pickerel - Fillets',
#    'Bread - Hot Dog Buns',
#    'Ketchup - Tomato',
#    'Appetizer - Mushroom Tart',
#    'Cod - Black Whole Fillet']},
#  {'CustomerID': 92673,
#   'Products': ['Yeast Dry - Fermipan',
#    'Milk Powder',
#    'Vinegar - Tarragon',
#    'Sprouts - Baby Pea Tendrils',
#    'Bread - Italian Roll With Herbs']},
#  {'CustomerID': 92951,
#   'Products': ['Chicken - Soup Base',
#    'Yoghurt Tubes',
#    'Butter - Unsalted',
#    'Hickory Smoke, Liquid',
#    'Tea - Jasmin Green']},
#  {'CustomerID': 92995,
#   'Products': ['Cinnamon Buns Sticky',
#    'Lettuce - California Mix',
#    'Wiberg Super Cure',
#    'Tart Shells - Sweet, 4',
#    'Bread - Roll, Canadian Dinner']},
#  {'CustomerID': 93417,
#   'Products': ['Lemonade - Natural, 591 Ml',
#    'Sun - Dried Tomatoes',
#    'Onions - Cippolini',
#    'Clam Nectar',
#    'Mustard Prepared']},
#  {'CustomerID': 93445,
#   'Products': ['Cake - Box Window 10x10x2.5',
#    'Lamb - Ground',
#    'Coffee - Dark Roast',
#    'Truffle Cups - Brown',
#    'Beef Wellington']},
#  {'CustomerID': 93505,
#   'Products': ['Cake - Mini Cheesecake',
#    'Cocoa Butter',
#    'Shrimp - 31/40',
#    'Bread - Raisin Walnut Oval',
#    'Bandage - Fexible 1x3']},
#  {'CustomerID': 93540,
#   'Products': ['Carbonated Water - Blackcherry',
#    'Cod - Black Whole Fillet',
#    'Hickory Smoke, Liquid',
#    'Gloves - Goldtouch Disposable',
#    'Chicken - Soup Base']},
#  {'CustomerID': 93692,
#   'Products': ['Muffin Batt - Blueberry Passion',
#    'Squid - Tubes / Tenticles 10/20',
#    'Oranges - Navel, 72',
#    'Hot Chocolate - Individual',
#    'Pasta - Penne, Rigate, Dry']},
#  {'CustomerID': 93882,
#   'Products': ['Soup - Canadian Pea, Dry Mix',
#    'Sobe - Tropical Energy',
#    'Veal - Sweetbread',
#    'Tea - Jasmin Green',
#    'Scallops 60/80 Iqf']},
#  {'CustomerID': 93918,
#   'Products': ['Soup Campbells - Italian Wedding',
#    'Cake - Mini Cheesecake',
#    'Lamb - Ground',
#    'Assorted Desserts',
#    'Milk - 1%']},
#  {'CustomerID': 94258,
#   'Products': ['Crush - Cream Soda',
#    'Tea - English Breakfast',
#    'Cheese Cloth No 100',
#    'Tuna - Salad Premix',
#    'Pork - Belly Fresh']},
#  {'CustomerID': 94420,
#   'Products': ['Duck - Breast',
#    'Wine - Redchard Merritt',
#    'Bread - Roll, Soft White Round',
#    'Beets - Candy Cane, Organic',
#    'Crab - Imitation Flakes']},
#  {'CustomerID': 94438,
#   'Products': ['Garlic - Elephant',
#    'Cinnamon Buns Sticky',
#    'Muffin - Carrot Individual Wrap',
#    'Cheese Cloth No 100',
#    'Oregano - Dry, Rubbed']},
#  {'CustomerID': 94547,
#   'Products': ['Apricots - Halves',
#    'Juice - Apple Cider',
#    'Veal - Inside, Choice',
#    'Olives - Kalamata',
#    'Cumin - Whole']},
#  {'CustomerID': 94599,
#   'Products': ['Water, Tap',
#    'Seedlings - Mix, Organic',
#    'Cheese Cloth No 100',
#    'Garlic - Elephant',
#    'Papayas']},
#  {'CustomerID': 94910,
#   'Products': ['Scampi Tail',
#    'Dc Hikiage Hira Huba',
#    'Cocoa Butter',
#    'Nut - Chestnuts, Whole',
#    'Bread - Multigrain']},
#  {'CustomerID': 94951,
#   'Products': ['Pork - Inside',
#    'Wine - Hardys Bankside Shiraz',
#    'Veal - Inside',
#    'Beef - Top Sirloin',
#    'Chicken - Soup Base']},
#  {'CustomerID': 95017,
#   'Products': ['Chocolate - Compound Coating',
#    'Doilies - 5, Paper',
#    'Wine - Charddonnay Errazuriz',
#    'Beef Wellington',
#    'Muffin Mix - Blueberry']},
#  {'CustomerID': 95034,
#   'Products': ['Fond - Neutral',
#    'Garlic - Primerba, Paste',
#    'Lemonade - Natural, 591 Ml',
#    'Cocoa Butter',
#    'Potatoes - Instant, Mashed']},
#  {'CustomerID': 95059,
#   'Products': ['Veal - Sweetbread',
#    'Peas - Pigeon, Dry',
#    'Watercress',
#    'Gloves - Goldtouch Disposable',
#    'Muffin - Carrot Individual Wrap']},
#  {'CustomerID': 95078,
#   'Products': ['Lentils - Red, Dry',
#    'Baking Powder',
#    'Scallops 60/80 Iqf',
#    'Salmon - Sockeye Raw',
#    'Beans - Kidney White']},
#  {'CustomerID': 95121,
#   'Products': ['Wine - Vineland Estate Semi - Dry',
#    'Water - Spring Water 500ml',
#    'Lettuce - Treviso',
#    'Apricots - Dried',
#    'Olive - Spread Tapenade']},
#  {'CustomerID': 95314,
#   'Products': ['Bread Crumbs - Panko',
#    'Cheese - Wine',
#    'Soup - Campbells, Beef Barley',
#    'Nut - Chestnuts, Whole',
#    'Salmon - Atlantic, Skin On']},
#  {'CustomerID': 95372,
#   'Products': ['Cheese - Camembert',
#    'Brandy - Bar',
#    'Oil - Safflower',
#    'Cheese - Cambozola',
#    'Turkey - Oven Roast Breast']},
#  {'CustomerID': 95819,
#   'Products': ['Anchovy Paste - 56 G Tube',
#    'Potatoes - Instant, Mashed',
#    'Cookies - Assorted',
#    'Cookies Cereal Nut',
#    'Pernod']},
#  {'CustomerID': 96024,
#   'Products': ['Beer - Alexander Kieths, Pale Ale',
#    'Tia Maria',
#    'Dried Figs',
#    'Muffin Batt - Blueberry Passion',
#    'Baking Powder']},
#  {'CustomerID': 96088,
#   'Products': ['Ice - Clear, 300 Lb For Carving',
#    'Clam Nectar',
#    'Crackers - Trio',
#    'Soup - Campbells Tomato Ravioli',
#    'Pomello']},
#  {'CustomerID': 96272,
#   'Products': ['Ecolab - Lime - A - Way 4/4 L',
#    'Bread Crumbs - Panko',
#    'Guinea Fowl',
#    'Sunflower Seed Raw',
#    'Bread - English Muffin']},
#  {'CustomerID': 96522,
#   'Products': ['Tea - Jasmin Green',
#    'Fuji Apples',
#    'Salmon - Atlantic, Skin On',
#    'Cocoa Butter',
#    'Crab - Imitation Flakes']},
#  {'CustomerID': 96524,
#   'Products': ['Baking Powder',
#    'Oranges - Navel, 72',
#    'Mussels - Frozen',
#    'Bouq All Italian - Primerba',
#    'Cocoa Butter']},
#  {'CustomerID': 96560,
#   'Products': ['Foam Cup 6 Oz',
#    'Yoghurt Tubes',
#    'Water - Aquafina Vitamin',
#    'Olives - Stuffed',
#    'Pepsi - Diet, 355 Ml']},
#  {'CustomerID': 96615,
#   'Products': ['Beer - Blue',
#    'Mangoes',
#    'Tart Shells - Sweet, 4',
#    'Beer - Alexander Kieths, Pale Ale',
#    'Bacardi Breezer - Tropical']},
#  {'CustomerID': 96666,
#   'Products': ['Wine - Valpolicella Masi',
#    'Skirt - 29 Foot',
#    'Oil - Shortening,liqud, Fry',
#    'Bread - English Muffin',
#    'Sauce - Rosee']},
#  {'CustomerID': 96684,
#   'Products': ['Peas - Pigeon, Dry',
#    'Wine - Wyndham Estate Bin 777',
#    'Zucchini - Yellow',
#    'Chinese Foods - Chicken',
#    'Bread - Bistro White']},
#  {'CustomerID': 97029,
#   'Products': ['Milk - 2%',
#    'Bay Leaf',
#    'Veal - Inside, Choice',
#    'Banana Turning',
#    'Wine - Vidal Icewine Magnotta']},
#  {'CustomerID': 97052,
#   'Products': ['Tea - Jasmin Green',
#    'Cocktail Napkin Blue',
#    'Blueberries',
#    'Lamb - Pieces, Diced',
#    'Bacardi Breezer - Tropical']},
#  {'CustomerID': 97063,
#   'Products': ['Beans - Kidney White',
#    'Initation Crab Meat',
#    'Pop Shoppe Cream Soda',
#    'Thermometer Digital',
#    'Squid U5 - Thailand']},
#  {'CustomerID': 97093,
#   'Products': ['Bar Mix - Pina Colada, 355 Ml',
#    'Soup Knorr Chili With Beans',
#    'Beer - Sleemans Cream Ale',
#    'Mushrooms - Black, Dried',
#    'Lime Cordial - Roses']},
#  {'CustomerID': 97201,
#   'Products': ['Olives - Kalamata',
#    'Tilapia - Fillets',
#    'Beans - Wax',
#    'Beef - Top Sirloin',
#    'Wine - White, Mosel Gold']},
#  {'CustomerID': 97282,
#   'Products': ['Ketchup - Tomato',
#    'Bread - Italian Corn Meal Poly',
#    'Wine - Vineland Estate Semi - Dry',
#    'Bouq All Italian - Primerba',
#    'Water - Spring Water 500ml']},
#  {'CustomerID': 97324,
#   'Products': ['Table Cloth 54x72 White',
#    'Coffee - Dark Roast',
#    'Scallops - Live In Shell',
#    'Bread Foccacia Whole',
#    'Pepper - Black, Whole']},
#  {'CustomerID': 97495,
#   'Products': ['Lettuce - Frisee',
#    'Soupcontfoam16oz 116con',
#    'Grapes - Red',
#    'Spoon - Soup, Plastic',
#    'Sprouts - Baby Pea Tendrils']},
#  {'CustomerID': 97697,
#   'Products': ['Cheese - Wine',
#    'Muffin - Carrot Individual Wrap',
#    'Lentils - Red, Dry',
#    'Meldea Green Tea Liquor',
#    'Coffee - Dark Roast']},
#  {'CustomerID': 97753,
#   'Products': ['Muffin Batt - Choc Chk',
#    'Papayas',
#    'Meldea Green Tea Liquor',
#    'Wine - Chablis 2003 Champs',
#    'Mussels - Frozen']},
#  {'CustomerID': 97769,
#   'Products': ['Pork - Loin, Bone - In',
#    'Potatoes - Idaho 100 Count',
#    'Pants Custom Dry Clean',
#    'Cake - Box Window 10x10x2.5',
#    'Pie Filling - Cherry']},
#  {'CustomerID': 97793,
#   'Products': ['Fenngreek Seed',
#    'Wine - Red, Colio Cabernet',
#    'Grenadine',
#    'Ice Cream Bar - Oreo Cone',
#    'Halibut - Fletches']},
#  {'CustomerID': 97900,
#   'Products': ['Placemat - Scallop, White',
#    'Rum - Mount Gay Eclipes',
#    'Tofu - Firm',
#    'Sobe - Tropical Energy',
#    'Cheese - Boursin, Garlic / Herbs']},
#  {'CustomerID': 97928,
#   'Products': ['Soup - Campbells, Lentil',
#    'Cheese - Brie,danish',
#    'Wiberg Super Cure',
#    'Pants Custom Dry Clean',
#    'Shrimp - 31/40']},
#  {'CustomerID': 98069,
#   'Products': ['Skirt - 29 Foot',
#    'Beans - Kidney White',
#    'Milk - 1%',
#    'Cheese - Taleggio D.o.p.',
#    'Sprouts - Baby Pea Tendrils']},
#  {'CustomerID': 98159,
#   'Products': ['Chips Potato Salt Vinegar 43g',
#    'Tea - English Breakfast',
#    'Wine - Red, Harrow Estates, Cab',
#    'Bread - Raisin Walnut Oval',
#    'Wine - Redchard Merritt']},
#  {'CustomerID': 98185,
#   'Products': ['Crackers - Trio',
#    'Pernod',
#    'Tea - Jasmin Green',
#    'Pastry - Choclate Baked',
#    'Peas - Pigeon, Dry']},
#  {'CustomerID': 98200,
#   'Products': ['Beans - Wax',
#    'Sherry - Dry',
#    'Pork - Hock And Feet Attached',
#    'Pears - Bosc',
#    'Soup - Campbells, Cream Of']}]

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
# to dataframe
df_cus_top_pro = pd.DataFrame(list_customers)
df_cus_top_pro
# Out:
#      CustomerID                                           Products
# 0            33  [Butter - Unsalted, Wine - Ej Gallo Sierra Val...
# 1           200  [Soup - Campbells Bean Medley, Muffin - Carrot...
# 2           264  [Soupfoamcont12oz 112con, Wine - Two Oceans Ca...
# 3           356  [Butter - Unsalted, Veal - Inside, Choice, Bee...
# 4           412  [Olive - Spread Tapenade, Sprouts - Baby Pea T...
# ..          ...                                                ...
# 995       97928  [Soup - Campbells, Lentil, Cheese - Brie,danis...
# 996       98069  [Skirt - 29 Foot, Beans - Kidney White, Milk -...
# 997       98159  [Chips Potato Salt Vinegar 43g, Tea - English ...
# 998       98185  [Crackers - Trio, Pernod, Tea - Jasmin Green, ...
# 999       98200  [Beans - Wax, Sherry - Dry, Pork - Hock And Fe...
#
# [1000 rows x 2 columns]

# %%
# list products to columns
df_split = pd.DataFrame(df_cus_top_pro['Products'].to_list(), columns=['ProductName1', 
                                                                       'ProductName2', 
                                                                       'ProductName3', 
                                                                       'ProductName4', 
                                                                       'ProductName5'])
df_cus_top_pro1 = pd.concat([df_cus_top_pro, df_split], axis=1)
df_cus_top_pro1
# Out:
#      CustomerID                                           Products  \
# 0            33  [Butter - Unsalted, Wine - Ej Gallo Sierra Val...
# 1           200  [Soup - Campbells Bean Medley, Muffin - Carrot...
# 2           264  [Soupfoamcont12oz 112con, Wine - Two Oceans Ca...
# 3           356  [Butter - Unsalted, Veal - Inside, Choice, Bee...
# 4           412  [Olive - Spread Tapenade, Sprouts - Baby Pea T...
# ..          ...                                                ...
# 995       97928  [Soup - Campbells, Lentil, Cheese - Brie,danis...
# 996       98069  [Skirt - 29 Foot, Beans - Kidney White, Milk -...
# 997       98159  [Chips Potato Salt Vinegar 43g, Tea - English ...
# 998       98185  [Crackers - Trio, Pernod, Tea - Jasmin Green, ...
# 999       98200  [Beans - Wax, Sherry - Dry, Pork - Hock And Fe...
#
#                       ProductName1                     ProductName2  \
# 0                Butter - Unsalted    Wine - Ej Gallo Sierra Valley
# 1     Soup - Campbells Bean Medley  Muffin - Carrot Individual Wrap
# 2          Soupfoamcont12oz 112con       Wine - Two Oceans Cabernet
# 3                Butter - Unsalted            Veal - Inside, Choice
# 4          Olive - Spread Tapenade      Sprouts - Baby Pea Tendrils
# ..                             ...                              ...
# 995       Soup - Campbells, Lentil             Cheese - Brie,danish
# 996                Skirt - 29 Foot             Beans - Kidney White
# 997  Chips Potato Salt Vinegar 43g          Tea - English Breakfast
# 998                Crackers - Trio                           Pernod
# 999                    Beans - Wax                     Sherry - Dry
#
#                         ProductName3                   ProductName4  \
# 0       Soup - Campbells Bean Medley  Wine - Blue Nun Qualitatswein
# 1                           Bay Leaf                  Pork - Kidney
# 2    Bread - Italian Roll With Herbs          Veal - Inside, Choice
# 3        Beets - Candy Cane, Organic         Nut - Chestnuts, Whole
# 4      Wine - Blue Nun Qualitatswein          Pepper - Black, Whole
# ..                               ...                            ...
# 995                Wiberg Super Cure         Pants Custom Dry Clean
# 996                        Milk - 1%       Cheese - Taleggio D.o.p.
# 997  Wine - Red, Harrow Estates, Cab     Bread - Raisin Walnut Oval
# 998               Tea - Jasmin Green        Pastry - Choclate Baked
# 999    Pork - Hock And Feet Attached                   Pears - Bosc
#
#                      ProductName5
# 0             Chicken - Soup Base
# 1                     Wanton Wrap
# 2    Fish - Scallops, Cold Smoked
# 3                   Lamb - Ground
# 4    Soup - Campbells Bean Medley
# ..                            ...
# 995                Shrimp - 31/40
# 996   Sprouts - Baby Pea Tendrils
# 997       Wine - Redchard Merritt
# 998            Peas - Pigeon, Dry
# 999    Soup - Campbells, Cream Of
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
# top 5 customer distance cosine

list_customers = []
# go every customer
### to test a few customers -> for idcustom in data_cus_pro['CustomerID'].unique()[:3]:
for idcustom in data_cus_pro['CustomerID'].unique():
    # choose similar customers
    similar_cus = pd.DataFrame(df_cosine_dist_cus.loc[idcustom].sort_values(ascending=False))[1:6]
    similar_customers = similar_cus.reset_index()[['CustomerID']]
    # join similar customers and data customers and products
    records_cus_pro = data_cus_pro.merge(similar_customers)
    # choose top products
    top_products = records_cus_pro.groupby(['ProductName'])[['Quantity']].sum().sort_values(by='Quantity', ascending=False)
    # products not purchased
    customer = data_cus_pro[(data_cus_pro['CustomerID'] == idcustom)]
    # join products and data customers and products
    records_top_pro = customer.merge(top_products, how='right', left_on='ProductName', right_on='ProductName')
    # select products not purchased
    list_products = list(records_top_pro[records_top_pro['CustomerID'].isnull()][:5]['ProductName'])
    # dictionary
    dict_customers = {}
    dict_customers['CustomerID'] = idcustom
    dict_customers['Products'] = list_products
    # add customer
    list_customers.append(dict_customers)

# to dataframe
df_cus_top_pro = pd.DataFrame(list_customers)
# list products to columns
df_split = pd.DataFrame(df_cus_top_pro['Products'].to_list(), columns=['ProductName1', 
                                                                       'ProductName2', 
                                                                       'ProductName3', 
                                                                       'ProductName4', 
                                                                       'ProductName5'])
df_cus_top_pro2 = pd.concat([df_cus_top_pro, df_split], axis=1)
df_cus_top_pro2
# Out:
#      CustomerID                                           Products  \
# 0            33  [Knife Plastic - White, Soup - Campbells, Beef...
# 1           200  [Longos - Grilled Salmon With Bbq, Snapple Lem...
# 2           264  [Pickerel - Fillets, Water - Mineral, Natural,...
# 3           356  [Bread - English Muffin, Olive - Spread Tapena...
# 4           412  [Salsify, Organic, Durian Fruit, Wine - Hardys...
# ..          ...                                                ...
# 995       97928  [Spoon - Soup, Plastic, Beef - Montreal Smoked...
# 996       98069  [Sprouts - Baby Pea Tendrils, Juice - Orange, ...
# 997       98159  [Water, Tap, Bananas, Wine - Redchard Merritt,...
# 998       98185  [Peas - Pigeon, Dry, Squid U5 - Thailand, Chee...
# 999       98200  [Cheese - Cheddarsliced, Wine - Toasted Head, ...
#
#                          ProductName1                    ProductName2  \
# 0               Knife Plastic - White   Soup - Campbells, Beef Barley
# 1    Longos - Grilled Salmon With Bbq               Snapple Lemon Tea
# 2                  Pickerel - Fillets        Water - Mineral, Natural
# 3              Bread - English Muffin         Olive - Spread Tapenade
# 4                    Salsify, Organic                    Durian Fruit
# ..                                ...                             ...
# 995             Spoon - Soup, Plastic  Beef - Montreal Smoked Brisket
# 996       Sprouts - Baby Pea Tendrils                  Juice - Orange
# 997                        Water, Tap                         Bananas
# 998                Peas - Pigeon, Dry             Squid U5 - Thailand
# 999            Cheese - Cheddarsliced             Wine - Toasted Head
#
#                         ProductName3                   ProductName4  \
# 0                 Onions - Cippolini      Tea - Herbal Sweet Dreams
# 1            General Purpose Trigger           Thyme - Lemon, Fresh
# 2           Snapple - Iced Tea Peach  Wine - Ej Gallo Sierra Valley
# 3                      Bagel - Plain  Pork - Hock And Feet Attached
# 4      Wine - Hardys Bankside Shiraz     Bread - Raisin Walnut Oval
# ..                               ...                            ...
# 995                     Blackberries            Cheese Cloth No 100
# 996  Muffin Batt - Blueberry Passion  Beer - Original Organic Lager
# 997          Wine - Redchard Merritt   Chocolate - Compound Coating
# 998         Cheese - Taleggio D.o.p.    Cheese - Brie, Triple Creme
# 999          Cheese - Cottage Cheese      Shrimp - Baby, Warm Water
#
#                          ProductName5
# 0              Muffin - Zero Transfat
# 1                  Tomatoes Tear Drop
# 2      French Pastry - Mini Chocolate
# 3                   Wiberg Super Cure
# 4            Gatorade - Xfactor Berry
# ..                                ...
# 995            Cake - Mini Cheesecake
# 996            Nut - Chestnuts, Whole
# 997  Longos - Grilled Salmon With Bbq
# 998                   Crackers - Trio
# 999         Jolt Cola - Electric Blue
#
# [1000 rows x 7 columns]

# %%
# top 5 customer distance correlation

list_customers = []
# go every customer
### to test a few customers -> for idcustom in data_cus_pro['CustomerID'].unique()[:3]:
for idcustom in data_cus_pro['CustomerID'].unique():
    # choose similar customers
    similar_cus = pd.DataFrame(df_corr_dist_cus.loc[idcustom].sort_values(ascending=False))[1:6]
    similar_customers = similar_cus.reset_index()[['CustomerID']]
    # join similar customers and data customers and products
    records_cus_pro = data_cus_pro.merge(similar_customers)
    # choose top products
    top_products = records_cus_pro.groupby(['ProductName'])[['Quantity']].sum().sort_values(by='Quantity', ascending=False)
    # products not purchased
    customer = data_cus_pro[(data_cus_pro['CustomerID'] == idcustom)]
    # join products and data customers and products
    records_top_pro = customer.merge(top_products, how='right', left_on='ProductName', right_on='ProductName')
    # select products not purchased
    list_products = list(records_top_pro[records_top_pro['CustomerID'].isnull()][:5]['ProductName'])
    # dictionary
    dict_customers = {}
    dict_customers['CustomerID'] = idcustom
    dict_customers['Products'] = list_products
    # add customer
    list_customers.append(dict_customers)

# to dataframe
df_cus_top_pro = pd.DataFrame(list_customers)
# list products to columns
df_split = pd.DataFrame(df_cus_top_pro['Products'].to_list(), columns=['ProductName1', 
                                                                       'ProductName2', 
                                                                       'ProductName3', 
                                                                       'ProductName4', 
                                                                       'ProductName5'])
df_cus_top_pro3 = pd.concat([df_cus_top_pro, df_split], axis=1)
df_cus_top_pro3
# Out:
#      CustomerID                                           Products  \
# 0            33  [Knife Plastic - White, Muffin - Zero Transfat...
# 1           200  [Otomegusa Dashi Konbu, Milk Powder, Potatoes ...
# 2           264  [Water - Mineral, Natural, Wine - Toasted Head...
# 3           356  [Cheese - Taleggio D.o.p., Coconut - Shredded,...
# 4           412  [Cake - Mini Cheesecake, Butter - Unsalted, Sa...
# ..          ...                                                ...
# 995       97928  [Lettuce - Treviso, Yogurt - Blueberry, 175 Gr...
# 996       98069  [Wine - Red, Colio Cabernet, Veal - Inside, So...
# 997       98159  [Water, Tap, Bananas, Wine - Redchard Merritt,...
# 998       98185  [Cheese - Taleggio D.o.p., Squid U5 - Thailand...
# 999       98200  [Juice - Orange, Pork - Hock And Feet Attached...
#
#                    ProductName1                   ProductName2  \
# 0         Knife Plastic - White         Muffin - Zero Transfat
# 1         Otomegusa Dashi Konbu                    Milk Powder
# 2      Water - Mineral, Natural            Wine - Toasted Head
# 3      Cheese - Taleggio D.o.p.      Coconut - Shredded, Sweet
# 4        Cake - Mini Cheesecake              Butter - Unsalted
# ..                          ...                            ...
# 995           Lettuce - Treviso     Yogurt - Blueberry, 175 Gr
# 996  Wine - Red, Colio Cabernet                  Veal - Inside
# 997                  Water, Tap                        Bananas
# 998    Cheese - Taleggio D.o.p.            Squid U5 - Thailand
# 999              Juice - Orange  Pork - Hock And Feet Attached
#
#                       ProductName3                   ProductName4  \
# 0                   Banana Turning             Crush - Cream Soda
# 1       Potatoes - Idaho 100 Count                Crackers - Trio
# 2         Snapple - Iced Tea Peach             Pickerel - Fillets
# 3           Cheese - Cheddarsliced  Ocean Spray - Kiwi Strawberry
# 4       Salmon - Atlantic, Skin On  Wine - Hardys Bankside Shiraz
# ..                             ...                            ...
# 995     Bread - Calabrese Baguette                Extract - Lemon
# 996        Soupfoamcont12oz 112con                  Peas - Frozen
# 997        Wine - Redchard Merritt   Chocolate - Compound Coating
# 998             Peas - Pigeon, Dry      Salmon Steak - Cohoe 8 Oz
# 999  Longos - Grilled Chicken With                 Cattail Hearts
#
#                          ProductName5
# 0                   Veal - Osso Bucco
# 1    Pail With Metal Handle 16l White
# 2                 Garbag Bags - Black
# 3                   Olives - Kalamata
# 4       Gloves - Goldtouch Disposable
# ..                                ...
# 995              Coffee - Irish Cream
# 996       Sprouts - Baby Pea Tendrils
# 997  Longos - Grilled Salmon With Bbq
# 998                 Veal - Osso Bucco
# 999                           Campari
#
# [1000 rows x 7 columns]

# %%
display(df_cus_top_pro1.loc[df_cus_top_pro1['CustomerID'] == 33]) # euclidean
display(df_cus_top_pro2.loc[df_cus_top_pro2['CustomerID'] == 33]) # cosine
display(df_cus_top_pro3.loc[df_cus_top_pro3['CustomerID'] == 33]) # correlation
# Out:
#    CustomerID                                           Products  \
# 0          33  [Butter - Unsalted, Wine - Ej Gallo Sierra Val...
#
#         ProductName1                   ProductName2  \
# 0  Butter - Unsalted  Wine - Ej Gallo Sierra Valley
#
#                    ProductName3                   ProductName4  \
# 0  Soup - Campbells Bean Medley  Wine - Blue Nun Qualitatswein
#
#           ProductName5
# 0  Chicken - Soup Base
#    CustomerID                                           Products  \
# 0          33  [Knife Plastic - White, Soup - Campbells, Beef...
#
#             ProductName1                   ProductName2        ProductName3  \
# 0  Knife Plastic - White  Soup - Campbells, Beef Barley  Onions - Cippolini
#
#                 ProductName4            ProductName5
# 0  Tea - Herbal Sweet Dreams  Muffin - Zero Transfat
#    CustomerID                                           Products  \
# 0          33  [Knife Plastic - White, Muffin - Zero Transfat...
#
#             ProductName1            ProductName2    ProductName3  \
# 0  Knife Plastic - White  Muffin - Zero Transfat  Banana Turning
#
#          ProductName4       ProductName5
# 0  Crush - Cream Soda  Veal - Osso Bucco

# %%
display(df_cus_top_pro1.loc[df_cus_top_pro1['CustomerID'] == 98069]) # euclidean
display(df_cus_top_pro2.loc[df_cus_top_pro2['CustomerID'] == 98069]) # cosine
display(df_cus_top_pro3.loc[df_cus_top_pro3['CustomerID'] == 98069]) # correlation
# Out:
#      CustomerID                                           Products  \
# 996       98069  [Skirt - 29 Foot, Beans - Kidney White, Milk -...
#
#         ProductName1          ProductName2 ProductName3  \
# 996  Skirt - 29 Foot  Beans - Kidney White    Milk - 1%
#
#                  ProductName4                 ProductName5
# 996  Cheese - Taleggio D.o.p.  Sprouts - Baby Pea Tendrils
#      CustomerID                                           Products  \
# 996       98069  [Sprouts - Baby Pea Tendrils, Juice - Orange, ...
#
#                     ProductName1    ProductName2  \
# 996  Sprouts - Baby Pea Tendrils  Juice - Orange
#
#                         ProductName3                   ProductName4  \
# 996  Muffin Batt - Blueberry Passion  Beer - Original Organic Lager
#
#                ProductName5
# 996  Nut - Chestnuts, Whole
#      CustomerID                                           Products  \
# 996       98069  [Wine - Red, Colio Cabernet, Veal - Inside, So...
#
#                    ProductName1   ProductName2             ProductName3  \
# 996  Wine - Red, Colio Cabernet  Veal - Inside  Soupfoamcont12oz 112con
#
#       ProductName4                 ProductName5
# 996  Peas - Frozen  Sprouts - Baby Pea Tendrils

# %% [markdown]
# ### Notes
# - Same client hasn't same suggested products, depends method to calculate distance
